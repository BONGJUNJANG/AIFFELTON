# %% [markdown]
# # 양방향LSTM model

# %%
import pandas as pd 
import pandas_datareader as pdr   
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
import torch
import random
import os
random.seed(123)
np.random.seed(123)
os.environ["PYTHONHASHSEED"] = str(123)
torch.manual_seed(123)
torch.cuda.manual_seed(123)               # type: ignore
torch.backends.cudnn.deterministic = True  # type: ignore
torch.backends.cudnn.benchmark = True      # type: ignore

# %% [markdown]
# ## 1. 데이터 로드 및 전처리

# %%
final2 = pd.read_csv('/home/jbj4278/ETH_data/final_dateadd') #feature포함 데이터

# %%
col = ['Date','Open', 'High', 'Low', 'Close', 'Volume','BTC_close', 'DXY', 'BTCD', 'Kimchi_premium', 'S&P500', 'Ethereum DeFi',
   'News_freq','signal']

# %%
final = final2.loc[:,col]

# %%
final
# Out:
#                        Date     Open     High      Low    Close      Volume  \
# 0       2021-03-23 22:09:00  2019000  2020000  2017000  2018000  101.666675
# 1       2021-03-23 22:10:00  2018000  2019000  2017000  2019000   20.106467
# 2       2021-03-23 22:11:00  2019000  2020000  2017000  2019000   17.313993
# 3       2021-03-23 22:12:00  2020000  2020000  2019000  2019000   36.582210
# 4       2021-03-23 22:13:00  2020000  2020000  2016000  2016000   63.727452
# ...                     ...      ...      ...      ...      ...         ...
# 523096  2022-03-23 15:15:00  3666000  3667000  3665000  3665000   39.688187
# 523097  2022-03-23 15:16:00  3666000  3669000  3665000  3668000   76.731647
# 523098  2022-03-23 15:17:00  3668000  3671000  3667000  3669000   96.039465
# 523099  2022-03-23 15:18:00  3667000  3674000  3663000  3663000   91.949217
# 523100  2022-03-23 15:19:00  3663000  3663000  3660000  3662000   29.505753
#
#          BTC_close     DXY       BTCD  Kimchi_premium   S&P500  Ethereum DeFi  \
# 0       65987000.0  92.350  61.201411       10.897713  3910.51   4.492662e+10
# 1       65985000.0  92.350  61.201411       10.897713  3910.51   4.492662e+10
# 2       66057000.0  92.350  61.201411       10.897713  3910.51   4.492662e+10
# 3       66012000.0  92.350  61.201411       10.897713  3910.51   4.492662e+10
# 4       66015000.0  92.350  61.201411       10.897713  3910.51   4.492662e+10
# ...            ...     ...        ...             ...      ...            ...
# 523096  51801000.0  98.793  42.584513       15.249800  4488.22   1.159212e+11
# 523097  51753000.0  98.793  42.584513       15.249800  4488.22   1.159212e+11
# 523098  51782000.0  98.793  42.584513       15.249800  4488.22   1.159212e+11
# 523099  51780000.0  98.793  42.584513       15.249800  4488.22   1.159212e+11
# 523100  51728000.0  98.793  42.584513       15.249800  4488.22   1.159212e+11
#
#         News_freq  signal
# 0           142.0     0.0
# 1           142.0     0.0
# 2           142.0     0.0
# 3           142.0     0.0
# 4           142.0     0.0
# ...           ...     ...
# 523096       57.0     0.0
# 523097       57.0     0.0
# 523098       57.0     0.0
# 523099       57.0     0.0
# 523100       57.0     0.0
#
# [523101 rows x 14 columns]

# %%
final.loc[final['signal']==0.0 , "signal"] = 2   # 보합 > 2로
final.loc[final['signal']==1.0 , "signal"] = 0  
 # 상승 > 0으로
final.loc[final['signal']==-1.0 , "signal"] = 1 #하락 > 1로
#(상승, 하락, 보합) > (0 ,1, 2)

# %%
final['signal'].value_counts()
# Out:
# 0.0    188025
# 1.0    171867
# 2.0    163209
# Name: signal, dtype: int64

# %%
def make_dataset(data, label, window_size):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
len_test = int(len(final)*0.2)
test_set = final[-len_test:]
tr_set = final[:-len_test]

# %%
test_set.shape
# Out:
# (104620, 14)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import wandb
# !wandb login
# Out:
# wandb: Currently logged in as: gyeongmocho. Use `wandb login --relogin` to force relogin

# %%
from torchmetrics.functional import f1_score,precision_recall

# %%
import time

def train(dataloader):
 
    model.train()
    total_acc, total_count = 0, 0
    start_time = time.time()

    
    loss_list = []
    for idx, (feature, label) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(feature.to(device))
        loss = criterion(predicted_label, label.to(device))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        
        total_count += label.size(0)
        loss_list.append(loss.item())
        
        if idx+1 % len(feature) == 0 and idx > 0:
            accuracy = total_acc/total_count
            loss_hist = np.mean(loss_list)
            elapsed = time.time() - start_time
            print(f'| epoch {epoch} | {idx}/{len(dataloader)} batches '
                f'| accuracy {accuracy} | loss {loss_hist}')
            total_acc, total_count = 0, 0
            start_time = time.time()

    wandb.log({'train_loss':np.mean(loss_list),'train_acc':total_acc/total_count})  
    return  total_acc/total_count,np.mean(loss_list)
    
            

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    loss_list = []
    
    score,precision,recall = 0, 0, 0
    with torch.no_grad():
        for idx, (feature, label) in enumerate(dataloader):
            feature, label = feature.to(device),label.to(device)
            predicted_label = model(feature.to(device))
            loss = criterion(predicted_label, label.to(device))
            
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
            loss_list.append(loss.item())
            
            
            
            score += f1_score(predicted_label.argmax(1).to(device), label,num_classes=3)
            precision += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[0]
            recall += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[1]
      
        
        score = score / len(loss_list)
        precision = precision / len(loss_list)
        recall = recall / len(loss_list)
            
    wandb.log({'val_loss':np.mean(loss_list), 'val_acc':total_acc/total_count,'f1_score':score,
              'precision':precision,'recall':recall})
    
    return total_acc/total_count, np.mean(loss_list),score

# %%
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self,path, patience=10, verbose=False, delta=0,):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class BlockingTimeSeriesSplit():
    def __init__(self, n_splits):
        self.n_splits = n_splits
    
    def get_n_splits(self, groups):
        return self.n_splits
    
    def split(self, X, y=None, groups=None):
        n_samples = len(X)
        k_fold_size = n_samples // self.n_splits
        indices = np.arange(n_samples)
    
        margin = 0
        for i in range(self.n_splits):
            start = i * k_fold_size
            stop = start + k_fold_size
            mid = int(0.9 * (stop - start)) + start
            yield indices[start: mid], indices[mid + margin: stop]

# %% [markdown]
# ## 모델정의

# %%
class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(BiLSTM, self).__init__() # 상속한 nn.Module에서 RNN에 해당하는 init 실행
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.num_classes = num_classes
        

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, bidirectional=True,batch_first=True)
        self.fc = nn.Linear(hidden_size*2, num_classes)
        

    def forward(self, x): 
        # input x : (BATCH, LENGTH, INPUT_SIZE) 
        # 최초의 hidden state와 cell state를 초기화
        # 만약 Bi-directional LSTM이라면 아래의 hidden and cell states의 첫번째 차원은 2*self.num_layers 
        h0 = torch.zeros(self.num_layers*2, x.size(0), self.hidden_size).to(device) # (BATCH SIZE, SEQ_LENGTH, HIDDEN_SIZE)
        c0 = torch.zeros(self.num_layers*2, x.size(0), self.hidden_size).to(device)  # hidden state와 동일

        # LSTM 순전파
        out, (hn, cn) = self.lstm(x, (h0, c0)) # out : (BATCH_SIZE, SEQ_LENGTH, HIDDEN_SIZE)  , hn이 lstm의 마지막 hidden state
        
        
        
        
        out = self.fc(out[:, -1, :])
        
        
        return out

# %%
window_size = 10

# %%
# parameters
input_size = 12
hidden_size = 20
num_layers = 1
num_classes = 3
lr = 0.0001

# %% [markdown]
# ## 모델학습

# %%
btss = BlockingTimeSeriesSplit(n_splits=5)
n_epochs = 100
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']
score_list = []
val_loss_list = []
voting_list = []
#cross validation

wandb.init(project='BiLSTM', entity='gyeongmoCho',name='BiLSTM_2lay_smallbatch')
#wandb.watch(model, criterion, log = "all" )


for idx,(tr_idx, val_idx) in enumerate(btss.split(tr_set)):
    
    train_data, val_data = tr_set.iloc[tr_idx], tr_set.iloc[val_idx]
    
    
    scaler = StandardScaler()
    scaler.fit(train_data[scale_cols])#for문을 돌면서 각 train, val을 스케일링ㅇ
    train_feature = scaler.transform(train_data[scale_cols])
    train_feature = pd.DataFrame(train_feature)                                 
    val_feature = scaler.transform(val_data[scale_cols])
    val_feature = pd.DataFrame(val_feature)   

    
    train_feature, train_label = make_dataset(train_feature, train_data['signal'], window_size)
    val_feature, val_label = make_dataset(val_feature, val_data['signal'], window_size)

    
    #모델 선언 
    
    model = BiLSTM(input_size,hidden_size, num_layers,num_classes).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0,verbose=True)
    total_accu = None


    print(model)
    
    early_stopping = EarlyStopping(patience = 10, verbose = True)



    #스케일링된 데이터를 torch Tensor로 변경
    val_feature = torch.FloatTensor(val_feature).to(device)
    val_label = torch.LongTensor(val_label).to(device)
    train_feature = torch.FloatTensor(train_feature).to(device)
    train_label  = torch.LongTensor(train_label).to(device)

    train_set = TensorDataset(train_feature,train_label)
    val_set = TensorDataset(val_feature,val_label)
    
    #데이터로더 사용
    BATCH_SIZE = 32
    train_dataloader = DataLoader(train_set , batch_size=BATCH_SIZE,shuffle=False)
    valid_dataloader = DataLoader(val_set, batch_size=BATCH_SIZE,shuffle=False)

    print(f"train_feature:{train_feature.shape},val_feature:{val_feature.shape}" )
    

    for epoch in range(1, n_epochs + 1):
        # 현재 learning rate 출력
        print(optimizer.param_groups[0]['lr'])
        epoch_start_time = time.time()
        accu_train, train_loss = train(train_dataloader)
        accu_val,val_loss,score = evaluate(valid_dataloader)
        if total_accu is not None and total_accu > accu_val:
            scheduler.step()
        else:
            total_accu = accu_val
        print('-' * 59)
        print(f'| end of epoch {epoch} | time: {time.time()- epoch_start_time}s | '
            f'valid accuracy {accu_val} | valid loss {val_loss}'
            ) 

        print('-' * 59)
        
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    score_list.append(score)
    print("save score")
    #voting_prob = soft_voting(valid_dataloader)
    #voting_list.append(voting_prob)
    print("save voting prob")
    
    PATH = f"/home/jbj4278/ETH_data/BiLSTM_2lay_smallbatch{idx}.pt"
    torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),


                }, PATH)
    print('-' * 59)
    print('Fold Finish')
    print('-' * 59)

score_list = list(map(float, score_list))
final_f1_score = np.mean(score_list)
print(final_f1_score)
wandb.log({'mean_f1_score':final_f1_score})
# Out:
# Finishing last run (ID:24l7uj7s) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score</td><td>▃▃▃▆▇▇▇▇▇▇▇▇▇▄▂▁▁▂▃▄▆▆▆▇▇▇▇▇▇▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>mean_f1_score</td><td>▁</td></tr><tr><td>precision</td><td>▂▂▃▇▇▇▇▇▇▇▇▇▇▃▁▁▁▂▃▄▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██</td></tr><tr><td>recall</td><td>▃▃▃▇▇▇▇▇▇▇▇▇▇▂▂▁▁▂▂▃▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▁▅▅▆▆▆▆▆▆▆▆▆▄▅▃▃▃▃▄▆▆▆▆▅▆▆▆▆▇██▆▆▆▆▆▆▆▆</td></tr><tr><td>train_loss</td><td>█▄▁▅▅▄▄▄▄▃▃▃▃▅▄▆▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▅▅▄▄▄▄▄▃</td></tr><tr><td>val_acc</td><td>▃▃▃▆▇▇▇▇▇▇▇▇▇▄▂▁▁▂▃▄▆▆▆▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>val_loss</td><td>▅▆█▃▃▂▂▂▂▂▂▂▂▄▅▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>f1_score</td><td>0.52636</td></tr><tr><td>mean_f1_score</td><td>0.41312</td></tr><tr><td>precision</td><td>0.49962</td></tr><tr><td>recall</td><td>0.5187</td></tr><tr><td>train_acc</td><td>0.38415</td></tr><tr><td>train_loss</td><td>1.08647</td></tr><tr><td>val_acc</td><td>0.52787</td></tr><tr><td>val_loss</td><td>1.0606</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">BiLSTM_2xhidden_smallbatch</strong>: <a href="https://wandb.ai/gyeongmocho/BiLSTM/runs/24l7uj7s" target="_blank">https://wandb.ai/gyeongmocho/BiLSTM/runs/24l7uj7s</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220606_065448-24l7uj7s/logs</code>
# Successfully finished last run (ID:24l7uj7s). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/jbj4278/wandb/run-20220606_074437-ci3qgauc</code>
# Syncing run <strong><a href="https://wandb.ai/gyeongmocho/BiLSTM/runs/ci3qgauc" target="_blank">BiLSTM_2lay_smallbatch</a></strong> to <a href="https://wandb.ai/gyeongmocho/BiLSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Adjusting learning rate of group 0 to 1.0000e-04.
# BiLSTM(
#   (lstm): LSTM(12, 20, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 11.863046407699585s | valid accuracy 0.4777511961722488 | valid loss 1.0886858574306693
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.088686).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 2 | time: 12.011900186538696s | valid accuracy 0.3757177033492823 | valid loss 1.0973013452901186
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 11.87902545928955s | valid accuracy 0.23229665071770336 | valid loss 1.1062778748628748
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 12.029812097549438s | valid accuracy 0.23516746411483253 | valid loss 1.1155087260799554
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 11.907421588897705s | valid accuracy 0.22882775119617224 | valid loss 1.12490225816501
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 11.829805850982666s | valid accuracy 0.22882775119617224 | valid loss 1.1343799554209673
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 7 | time: 11.76400351524353s | valid accuracy 0.22882775119617224 | valid loss 1.1438751659775508
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 11.868526458740234s | valid accuracy 0.22882775119617224 | valid loss 1.1533316182726212
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 11.746317863464355s | valid accuracy 0.22882775119617224 | valid loss 1.1627018233291975
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 11.688910484313965s | valid accuracy 0.22882775119617224 | valid loss 1.1719464759790261
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 11.601547718048096s | valid accuracy 0.22882775119617224 | valid loss 1.181033274599614
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# save voting prob
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 0.0001
# -----------------------------------------------------------
# | end of epoch 71 | time: 11.762580871582031s | valid accuracy 0.4717703349282297 | valid loss 1.0696963069548133
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 0.0001
# -----------------------------------------------------------
# | end of epoch 72 | time: 11.789371490478516s | valid accuracy 0.4717703349282297 | valid loss 1.0697411096278038
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 0.0001
# -----------------------------------------------------------
# | end of epoch 73 | time: 11.75534987449646s | valid accuracy 0.4717703349282297 | valid loss 1.0697907448269939
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# save voting prob
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# BiLSTM(
#   (lstm): LSTM(12, 20, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 11.690942764282227s | valid accuracy 0.3063397129186603 | valid loss 1.1033022135268642
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.103302).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 2 | time: 11.621411323547363s | valid accuracy 0.3053827751196172 | valid loss 1.1040228860068868
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 11.626307487487793s | valid accuracy 0.30574162679425837 | valid loss 1.1047325509650108
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 11.668008804321289s | valid accuracy 0.30358851674641146 | valid loss 1.1054279424307
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 11.779003381729126s | valid accuracy 0.30227272727272725 | valid loss 1.1061062517056939
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 11.683962345123291s | valid accuracy 0.30035885167464116 | valid loss 1.1067652003910706
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 7 | time: 11.71085810661316s | valid accuracy 0.2992822966507177 | valid loss 1.107403062909614
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 11.518142223358154s | valid accuracy 0.2971291866028708 | valid loss 1.1080184387796708
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 11.619122982025146s | valid accuracy 0.29545454545454547 | valid loss 1.1086102521601524
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 11.479330062866211s | valid accuracy 0.2958133971291866 | valid loss 1.1091778769747902
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 11.726074934005737s | valid accuracy 0.2979665071770335 | valid loss 1.1097207535769193
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# save voting prob
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# BiLSTM(
#   (lstm): LSTM(12, 20, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 11.623381614685059s | valid accuracy 0.17954545454545454 | valid loss 1.1154918270256684
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.115492).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 11.646568298339844s | valid accuracy 0.17954545454545454 | valid loss 1.113418603671416
# -----------------------------------------------------------
# Validation loss decreased (1.115492 --> 1.113419).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 11.634982109069824s | valid accuracy 0.1785885167464115 | valid loss 1.111466612979656
# -----------------------------------------------------------
# Validation loss decreased (1.113419 --> 1.111467).  Saving model ...
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 11.569835901260376s | valid accuracy 0.17045454545454544 | valid loss 1.1096277623686173
# -----------------------------------------------------------
# Validation loss decreased (1.111467 --> 1.109628).  Saving model ...
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 11.70796799659729s | valid accuracy 0.1700956937799043 | valid loss 1.1078952054941018
# -----------------------------------------------------------
# Validation loss decreased (1.109628 --> 1.107895).  Saving model ...
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 11.754990100860596s | valid accuracy 0.16555023923444975 | valid loss 1.1062623367054771
# -----------------------------------------------------------
# Validation loss decreased (1.107895 --> 1.106262).  Saving model ...
# 9.960573506572391e-05
# -----------------------------------------------------------
# | end of epoch 7 | time: 11.675038814544678s | valid accuracy 0.2151913875598086 | valid loss 1.1047229876045053
# -----------------------------------------------------------
# Validation loss decreased (1.106262 --> 1.104723).  Saving model ...
# 9.960573506572391e-05
# -----------------------------------------------------------
# | end of epoch 8 | time: 11.82431173324585s | valid accuracy 0.4150717703349282 | valid loss 1.1032682020245617
# -----------------------------------------------------------
# Validation loss decreased (1.104723 --> 1.103268).  Saving model ...
# 9.960573506572391e-05
# -----------------------------------------------------------
# | end of epoch 9 | time: 11.74330735206604s | valid accuracy 0.4631578947368421 | valid loss 1.1018922729346587
# -----------------------------------------------------------
# Validation loss decreased (1.103268 --> 1.101892).  Saving model ...
# 9.960573506572391e-05
# -----------------------------------------------------------
# | end of epoch 10 | time: 11.601523637771606s | valid accuracy 0.4705741626794258 | valid loss 1.100590068420381
# -----------------------------------------------------------
# Validation loss decreased (1.101892 --> 1.100590).  Saving model ...
# 9.960573506572391e-05
# -----------------------------------------------------------
# | end of epoch 11 | time: 11.671776056289673s | valid accuracy 0.47320574162679424 | valid loss 1.099356726380705
# -----------------------------------------------------------
# Validation loss decreased (1.100590 --> 1.099357).  Saving model ...
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 12 | time: 11.585461616516113s | valid accuracy 0.4666267942583732 | valid loss 1.0981878984065456
# -----------------------------------------------------------
# Validation loss decreased (1.099357 --> 1.098188).  Saving model ...
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 13 | time: 11.714509963989258s | valid accuracy 0.4666267942583732 | valid loss 1.0970818787130692
# -----------------------------------------------------------
# Validation loss decreased (1.098188 --> 1.097082).  Saving model ...
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 14 | time: 11.875494718551636s | valid accuracy 0.4666267942583732 | valid loss 1.096034987282207
# -----------------------------------------------------------
# Validation loss decreased (1.097082 --> 1.096035).  Saving model ...
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 15 | time: 11.708608388900757s | valid accuracy 0.4666267942583732 | valid loss 1.0950437019799502
# -----------------------------------------------------------
# Validation loss decreased (1.096035 --> 1.095044).  Saving model ...
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 16 | time: 11.864080429077148s | valid accuracy 0.4666267942583732 | valid loss 1.0941047500108034
# -----------------------------------------------------------
# Validation loss decreased (1.095044 --> 1.094105).  Saving model ...
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 17 | time: 11.723978757858276s | valid accuracy 0.4666267942583732 | valid loss 1.0932150947228643
# -----------------------------------------------------------
# Validation loss decreased (1.094105 --> 1.093215).  Saving model ...
# 9.75528258147577e-05
# Adjusting learning rate of group 0 to 9.7044e-05.
# -----------------------------------------------------------
# | end of epoch 18 | time: 11.641185760498047s | valid accuracy 0.4666267942583732 | valid loss 1.0923718644007472
# -----------------------------------------------------------
# Validation loss decreased (1.093215 --> 1.092372).  Saving model ...
# 9.70440384477113e-05
# Adjusting learning rate of group 0 to 9.6489e-05.
# -----------------------------------------------------------
# | end of epoch 19 | time: 11.738006353378296s | valid accuracy 0.4666267942583732 | valid loss 1.0915723568155566
# -----------------------------------------------------------
# Validation loss decreased (1.092372 --> 1.091572).  Saving model ...
# 9.64888242944126e-05
# Adjusting learning rate of group 0 to 9.5888e-05.
# -----------------------------------------------------------
# | end of epoch 20 | time: 11.748971462249756s | valid accuracy 0.4666267942583732 | valid loss 1.0908140430923636
# -----------------------------------------------------------
# Validation loss decreased (1.091572 --> 1.090814).  Saving model ...
# 9.588773128419907e-05
# Adjusting learning rate of group 0 to 9.5241e-05.
# -----------------------------------------------------------
# | end of epoch 21 | time: 11.64694595336914s | valid accuracy 0.4666267942583732 | valid loss 1.0900945460978355
# -----------------------------------------------------------
# Validation loss decreased (1.090814 --> 1.090095).  Saving model ...
# 9.5241352623301e-05
# Adjusting learning rate of group 0 to 9.4550e-05.
# -----------------------------------------------------------
# | end of epoch 22 | time: 11.684951543807983s | valid accuracy 0.4666267942583732 | valid loss 1.089411550123273
# -----------------------------------------------------------
# Validation loss decreased (1.090095 --> 1.089412).  Saving model ...
# 9.455032620941843e-05
# Adjusting learning rate of group 0 to 9.3815e-05.
# -----------------------------------------------------------
# | end of epoch 23 | time: 11.62728500366211s | valid accuracy 0.4666267942583732 | valid loss 1.0887631241601843
# -----------------------------------------------------------
# Validation loss decreased (1.089412 --> 1.088763).  Saving model ...
# 9.381533400219321e-05
# Adjusting learning rate of group 0 to 9.3037e-05.
# -----------------------------------------------------------
# | end of epoch 24 | time: 11.659415483474731s | valid accuracy 0.4666267942583732 | valid loss 1.0881470751216393
# -----------------------------------------------------------
# Validation loss decreased (1.088763 --> 1.088147).  Saving model ...
# 9.303710135019722e-05
# Adjusting learning rate of group 0 to 9.2216e-05.
# -----------------------------------------------------------
# | end of epoch 25 | time: 11.676646947860718s | valid accuracy 0.4666267942583732 | valid loss 1.0875616414856364
# -----------------------------------------------------------
# Validation loss decreased (1.088147 --> 1.087562).  Saving model ...
# 9.22163962751008e-05
# Adjusting learning rate of group 0 to 9.1354e-05.
# -----------------------------------------------------------
# | end of epoch 26 | time: 11.742799997329712s | valid accuracy 0.4666267942583732 | valid loss 1.0870050483077538
# -----------------------------------------------------------
# Validation loss decreased (1.087562 --> 1.087005).  Saving model ...
# 9.135402871372814e-05
# Adjusting learning rate of group 0 to 9.0451e-05.
# -----------------------------------------------------------
# | end of epoch 27 | time: 11.808053255081177s | valid accuracy 0.4666267942583732 | valid loss 1.0864757456397283
# -----------------------------------------------------------
# Validation loss decreased (1.087005 --> 1.086476).  Saving model ...
# 9.045084971874742e-05
# Adjusting learning rate of group 0 to 8.9508e-05.
# -----------------------------------------------------------
# | end of epoch 28 | time: 11.725397825241089s | valid accuracy 0.4666267942583732 | valid loss 1.0859721316636064
# -----------------------------------------------------------
# Validation loss decreased (1.086476 --> 1.085972).  Saving model ...
# 8.950775061878456e-05
# Adjusting learning rate of group 0 to 8.8526e-05.
# -----------------------------------------------------------
# | end of epoch 29 | time: 11.824910640716553s | valid accuracy 0.4666267942583732 | valid loss 1.0854929025846582
# -----------------------------------------------------------
# Validation loss decreased (1.085972 --> 1.085493).  Saving model ...
# 8.852566213878951e-05
# Adjusting learning rate of group 0 to 8.7506e-05.
# -----------------------------------------------------------
# | end of epoch 30 | time: 11.728182792663574s | valid accuracy 0.4666267942583732 | valid loss 1.0850365696517565
# -----------------------------------------------------------
# Validation loss decreased (1.085493 --> 1.085037).  Saving model ...
# 8.750555348152303e-05
# Adjusting learning rate of group 0 to 8.6448e-05.
# -----------------------------------------------------------
# | end of epoch 31 | time: 11.813233375549316s | valid accuracy 0.4666267942583732 | valid loss 1.0846019996941545
# -----------------------------------------------------------
# Validation loss decreased (1.085037 --> 1.084602).  Saving model ...
# 8.644843137107063e-05
# Adjusting learning rate of group 0 to 8.5355e-05.
# -----------------------------------------------------------
# | end of epoch 32 | time: 11.793013095855713s | valid accuracy 0.4666267942583732 | valid loss 1.0841879403318158
# -----------------------------------------------------------
# Validation loss decreased (1.084602 --> 1.084188).  Saving model ...
# 8.535533905932742e-05
# Adjusting learning rate of group 0 to 8.4227e-05.
# -----------------------------------------------------------
# | end of epoch 33 | time: 11.75119400024414s | valid accuracy 0.4666267942583732 | valid loss 1.0837933496209502
# -----------------------------------------------------------
# Validation loss decreased (1.084188 --> 1.083793).  Saving model ...
# 8.422735529643448e-05
# Adjusting learning rate of group 0 to 8.3066e-05.
# -----------------------------------------------------------
# | end of epoch 34 | time: 11.75158143043518s | valid accuracy 0.4666267942583732 | valid loss 1.083417174925331
# -----------------------------------------------------------
# Validation loss decreased (1.083793 --> 1.083417).  Saving model ...
# 8.306559326618263e-05
# Adjusting learning rate of group 0 to 8.1871e-05.
# -----------------------------------------------------------
# | end of epoch 35 | time: 11.679049253463745s | valid accuracy 0.4666267942583732 | valid loss 1.0830584325408208
# -----------------------------------------------------------
# Validation loss decreased (1.083417 --> 1.083058).  Saving model ...
# 8.187119948743452e-05
# Adjusting learning rate of group 0 to 8.0645e-05.
# -----------------------------------------------------------
# | end of epoch 36 | time: 11.801690101623535s | valid accuracy 0.4666267942583732 | valid loss 1.08271624819013
# -----------------------------------------------------------
# Validation loss decreased (1.083058 --> 1.082716).  Saving model ...
# 8.064535268264887e-05
# Adjusting learning rate of group 0 to 7.9389e-05.
# -----------------------------------------------------------
# | end of epoch 37 | time: 11.661332607269287s | valid accuracy 0.4666267942583732 | valid loss 1.0823897903657143
# -----------------------------------------------------------
# Validation loss decreased (1.082716 --> 1.082390).  Saving model ...
# 7.938926261462371e-05
# Adjusting learning rate of group 0 to 7.8104e-05.
# -----------------------------------------------------------
# | end of epoch 38 | time: 11.729317426681519s | valid accuracy 0.4666267942583732 | valid loss 1.0820781613579233
# -----------------------------------------------------------
# Validation loss decreased (1.082390 --> 1.082078).  Saving model ...
# 7.810416889260659e-05
# Adjusting learning rate of group 0 to 7.6791e-05.
# -----------------------------------------------------------
# | end of epoch 39 | time: 11.723843574523926s | valid accuracy 0.4666267942583732 | valid loss 1.0817806939132342
# -----------------------------------------------------------
# ...
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 11.721561193466187s | valid accuracy 0.22811004784688996 | valid loss 1.1165293632572844
# -----------------------------------------------------------
# Validation loss decreased (1.118593 --> 1.116529).  Saving model ...
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 11.536312103271484s | valid accuracy 0.22045454545454546 | valid loss 1.1146336762049727
# -----------------------------------------------------------
# Validation loss decreased (1.116529 --> 1.114634).  Saving model ...
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 11.615254163742065s | valid accuracy 0.2574162679425837 | valid loss 1.112892214351028
# -----------------------------------------------------------
# Validation loss decreased (1.114634 --> 1.112892).  Saving model ...
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 7 | time: 11.80499529838562s | valid accuracy 0.2582535885167464 | valid loss 1.1112926832137218
# -----------------------------------------------------------
# Validation loss decreased (1.112892 --> 1.111293).  Saving model ...
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 11.801477670669556s | valid accuracy 0.2582535885167464 | valid loss 1.1098239526493858
# -----------------------------------------------------------
# Validation loss decreased (1.111293 --> 1.109824).  Saving model ...
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 11.67383623123169s | valid accuracy 0.2582535885167464 | valid loss 1.10847572857187
# -----------------------------------------------------------
# Validation loss decreased (1.109824 --> 1.108476).  Saving model ...
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 11.832218170166016s | valid accuracy 0.2578947368421053 | valid loss 1.1072385197377388
# -----------------------------------------------------------
# Validation loss decreased (1.108476 --> 1.107239).  Saving model ...
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 11.56102967262268s | valid accuracy 0.25885167464114833 | valid loss 1.1061035417418443
# -----------------------------------------------------------
# Validation loss decreased (1.107239 --> 1.106104).  Saving model ...
# 9.75528258147577e-05
# Adjusting learning rate of group 0 to 9.7044e-05.
# -----------------------------------------------------------
# | end of epoch 12 | time: 11.750030994415283s | valid accuracy 0.2595693779904306 | valid loss 1.105062914941147
# -----------------------------------------------------------
# Validation loss decreased (1.106104 --> 1.105063).  Saving model ...
# 9.70440384477113e-05
# Adjusting learning rate of group 0 to 9.6489e-05.
# -----------------------------------------------------------
# | end of epoch 13 | time: 11.711077690124512s | valid accuracy 0.2595693779904306 | valid loss 1.1041092103674213
  Saving model ...
# 9.455032620941843e-05
# -----------------------------------------------------------
# | end of epoch 30 | time: 11.632431030273438s | valid accuracy 0.34581339712918663 | valid loss 1.0962150028643718
# -----------------------------------------------------------
# Validation loss decreased (1.096392 --> 1.096215).  Saving model ...
# 9.455032620941843e-05
# -----------------------------------------------------------
# | end of epoch 31 | time: 11.627506494522095s | valid accuracy 0.34868421052631576 | valid loss 1.0960623132818528
# -----------------------------------------------------------
# Validation loss decreased (1.096215 --> 1.096062).  Saving model ...
# 9.455032620941843e-05
# Adjusting learning rate of group 0 to 9.3815e-05.
# -----------------------------------------------------------
# | end of epoch 32 | time: 11.731422424316406s | valid accuracy 0.3485645933014354 | valid loss 1.0959326941093415
# -----------------------------------------------------------
# Validation loss decreased (1.096062 --> 1.095933).  Saving model ...
# 9.381533400219321e-05
# Adjusting learning rate of group 0 to 9.3037e-05.
# -----------------------------------------------------------
# | end of epoch 33 | time: 11.78488302230835s | valid accuracy 0.3473684210526316 | valid loss 1.095825763149116
# -----------------------------------------------------------
# Validation loss decreased (1.095933 --> 1.095826).  Saving model ...
# 9.303710135019722e-05
# Adjusting learning rate of group 0 to 9.2216e-05.
# -----------------------------------------------------------
# | end of epoch 34 | time: 11.765809059143066s | valid accuracy 0.3473684210526316 | valid loss 1.0957400678223326
# -----------------------------------------------------------
# Validation loss decreased (1.095826 --> 1.095740).  Saving model ...
# 9.22163962751008e-05
# Adjusting learning rate of group 0 to 9.1354e-05.
# -----------------------------------------------------------
# | end of epoch 35 | time: 11.685389995574951s | valid accuracy 0.34760765550239237 | valid loss 1.0956741571426392
# -----------------------------------------------------------
# Validation loss decreased (1.095740 --> 1.095674).  Saving model ...
# 9.135402871372814e-05
# Adjusting learning rate of group 0 to 9.0451e-05.
# -----------------------------------------------------------
# | end of epoch 36 | time: 11.616836309432983s | valid accuracy 0.3479665071770335 | valid loss 1.095626671578138
# -----------------------------------------------------------
# Validation loss decreased (1.095674 --> 1.095627).  Saving model ...
# 9.045084971874742e-05
# Adjusting learning rate of group 0 to 8.9508e-05.
# -----------------------------------------------------------
# | end of epoch 37 | time: 11.627761363983154s | valid accuracy 0.3478468899521531 | valid loss 1.0955963193915272
# -----------------------------------------------------------
# Validation loss decreased (1.095627 --> 1.095596).  Saving model ...
# 8.950775061878456e-05
# Adjusting learning rate of group 0 to 8.8526e-05.
# -----------------------------------------------------------
# | end of epoch 38 | time: 11.571208715438843s | valid accuracy 0.3477272727272727 | valid loss 1.0955820017643558
# -----------------------------------------------------------
# Validation loss decreased (1.095596 --> 1.095582).  Saving model ...
# 8.852566213878951e-05
# Adjusting learning rate of group 0 to 8.7506e-05.
# -----------------------------------------------------------
# | end of epoch 39 | time: 11.668556928634644s | valid accuracy 0.3479665071770335 | valid loss 1.09558252455624
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 8.750555348152303e-05
# Adjusting learning rate of group 0 to 8.6448e-05.
# -----------------------------------------------------------
# | end of epoch 40 | time: 11.696653604507446s | valid accuracy 0.3478468899521531 | valid loss 1.0955968474158804
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 8.644843137107063e-05
# Adjusting learning rate of group 0 to 8.5355e-05.
# -----------------------------------------------------------
# | end of epoch 41 | time: 11.74193811416626s | valid accuracy 0.34748803827751196 | valid loss 1.095624017578955
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 8.535533905932742e-05
# Adjusting learning rate of group 0 to 8.4227e-05.
# -----------------------------------------------------------
# | end of epoch 42 | time: 11.659666299819946s | valid accuracy 0.34760765550239237 | valid loss 1.0956630074340878
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 8.422735529643448e-05
# Adjusting learning rate of group 0 to 8.3066e-05.
# -----------------------------------------------------------
# | end of epoch 43 | time: 11.606998205184937s | valid accuracy 0.34760765550239237 | valid loss 1.0957129049392147
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 8.306559326618263e-05
# Adjusting learning rate of group 0 to 8.1871e-05.
# -----------------------------------------------------------
# | end of epoch 44 | time: 11.598143577575684s | valid accuracy 0.3473684210526316 | valid loss 1.0957729707237418
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 8.187119948743452e-05
# Adjusting learning rate of group 0 to 8.0645e-05.
# -----------------------------------------------------------
# | end of epoch 45 | time: 11.605095624923706s | valid accuracy 0.34748803827751196 | valid loss 1.095842239510922
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 8.064535268264887e-05
# Adjusting learning rate of group 0 to 7.9389e-05.
# -----------------------------------------------------------
# | end of epoch 46 | time: 11.763427257537842s | valid accuracy 0.3473684210526316 | valid loss 1.0959201273117356
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 7.938926261462371e-05
# Adjusting learning rate of group 0 to 7.8104e-05.
# -----------------------------------------------------------
# | end of epoch 47 | time: 11.66008734703064s | valid accuracy 0.3473684210526316 | valid loss 1.0960057805512697
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 7.810416889260659e-05
# Adjusting learning rate of group 0 to 7.6791e-05.
# -----------------------------------------------------------
# | end of epoch 48 | time: 11.699768781661987s | valid accuracy 0.3478468899521531 | valid loss 1.0960984983062017
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# save voting prob
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# 0.3627146929502487

# %% [markdown]
# ## f1-score의 fold별 평균이 가장 좋았던 모델로 Test set 성능 측정
# hidden state = 20 , batch = 32, lr = 0.0001, mean_f1score

# %%
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']
scaler = StandardScaler()
scaler.fit(tr_set[scale_cols])#for문을 돌면서 각 train, val을 스케일링
tr_feature = scaler.transform(tr_set[scale_cols])
tr_feature = pd.DataFrame(tr_feature)                                 
test_feature = scaler.transform(test_set[scale_cols])
test_feature = pd.DataFrame(test_feature)   


test_feature, test_label = make_dataset(test_feature, test_set['signal'], window_size)


#스케일링된 데이터를 torch Tensor로 변경
test_feature = torch.FloatTensor(test_feature).to(device)
test_label  = torch.LongTensor(test_label).to(device)

final_test_set = TensorDataset(test_feature,test_label)


#데이터로더 사용
BATCH_SIZE = 32
test_dataloader = DataLoader(final_test_set , batch_size=BATCH_SIZE,shuffle=False)

# %%
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']



   
scaler = StandardScaler()
scaler.fit(tr_set[scale_cols])#for문을 돌면서 각 train, val을 스케일링ㅇ
train_feature = scaler.transform(tr_set[scale_cols])
train_feature = pd.DataFrame(train_feature)                                 
 

    
train_feature, train_label = make_dataset(train_feature, tr_set['signal'], window_size)
  

train_feature = torch.FloatTensor(train_feature).to(device)
train_label  = torch.LongTensor(train_label).to(device)

train_set = TensorDataset(train_feature,train_label)


#데이터로더 사용
BATCH_SIZE = 32
final_dataloader = DataLoader(train_set , batch_size=BATCH_SIZE,shuffle=False)

# %%
#모델 저장 경로
path = f"/home/jbj4278/ETH_data/biLSTM_final_model.pt"

# %%
# parameters
input_size = 12
hidden_size = 20
num_layers = 1
num_classes = 3
lr = 0.0001

# %%
model = BiLSTM(input_size,hidden_size, num_layers,num_classes).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0,verbose=True)
total_accu = None
# Out:
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
import time

def train(dataloader):
 
    model.train()
    total_acc, total_count = 0, 0
    start_time = time.time()

    
    loss_list = []
    for idx, (feature, label) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(feature.to(device))
        loss = criterion(predicted_label, label.to(device))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        
        total_count += label.size(0)
        loss_list.append(loss.item())
        
        if idx+1 % len(feature) == 0 and idx > 0:
            accuracy = total_acc/total_count
            loss_hist = np.mean(loss_list)
            elapsed = time.time() - start_time
            print(f'| epoch {epoch} | {idx}/{len(dataloader)} batches '
                f'| accuracy {accuracy} | loss {loss_hist}')
            total_acc, total_count = 0, 0
            start_time = time.time()

      
    return  total_acc/total_count,np.mean(loss_list)
    
            

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    loss_list = []
    pred_label = []
    pred_prob = []
    score,precision,recall = 0, 0, 0
    with torch.no_grad():
        for idx, (feature, label) in enumerate(dataloader):
            feature, label = feature.to(device),label.to(device)
            predicted_label = model(feature.to(device))
            loss = criterion(predicted_label, label.to(device))
            
            
            sm = nn.Softmax(dim=1)
            probabilities = sm(predicted_label)
            prob_arr = (probabilities.detach().cpu().numpy())[0]
            pred_prob.append(prob_arr)
            
            
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
            loss_list.append(loss.item())
            pred_label.append(predicted_label.argmax(1))
            
            
            score += f1_score(predicted_label.argmax(1).to(device), label,num_classes=3)
            precision += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[0]
            recall += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[1]
      
        
        score = score / len(loss_list)
        precision = precision / len(loss_list)
        recall = recall / len(loss_list)
            
    
    
    return total_acc/total_count, np.mean(loss_list),score,pred_label,pred_prob

# %% [markdown]
# ## 모델 학습

# %%
n_epochs = 100
early_stopping = EarlyStopping(path,patience = 3, verbose = True)


for epoch in range(1, n_epochs + 1):
    # 현재 learning rate 출력
    print(optimizer.param_groups[0]['lr'])
    epoch_start_time = time.time()
    accu_train, train_loss = train(final_dataloader)
    accu_test,test_loss,score,label,prob = evaluate(test_dataloader)
    if total_accu is not None and total_accu > accu_test:
        scheduler.step()
    else:
        total_accu = accu_test
    print('-' * 59)
    print(f'| end of epoch {epoch} | time: {time.time()- epoch_start_time}s | '
        f'valid accuracy {accu_test} | valid loss {test_loss}'
        ) 

    print('-' * 59)

    early_stopping(test_loss, model)
    if early_stopping.early_stop:
        print("Early stopping")
        break
print(score)
torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),


                }, path)
# Out:
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 55.16508150100708s | valid accuracy 0.3486282382181436 | valid loss 1.0983669009959662
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.098367).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 55.447038888931274s | valid accuracy 0.35008125418220054 | valid loss 1.0978594035365894
# -----------------------------------------------------------
# Validation loss decreased (1.098367 --> 1.097859).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 55.35290479660034s | valid accuracy 0.3499952203422235 | valid loss 1.0973830163296574
# -----------------------------------------------------------
# Validation loss decreased (1.097859 --> 1.097383).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 4 | time: 55.33049702644348s | valid accuracy 0.3514577956218335 | valid loss 1.0969147376328798
# -----------------------------------------------------------
# Validation loss decreased (1.097383 --> 1.096915).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 5 | time: 55.43091893196106s | valid accuracy 0.35444986138992446 | valid loss 1.0964487776479226
# -----------------------------------------------------------
# Validation loss decreased (1.096915 --> 1.096449).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 6 | time: 55.63022780418396s | valid accuracy 0.36354077048083355 | valid loss 1.0959863975871957
# -----------------------------------------------------------
# Validation loss decreased (1.096449 --> 1.095986).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 7 | time: 55.79605269432068s | valid accuracy 0.36838734346620783 | valid loss 1.0955306536743035
# -----------------------------------------------------------
# Validation loss decreased (1.095986 --> 1.095531).  Saving model ...
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 55.82201790809631s | valid accuracy 0.36772775069305036 | valid loss 1.0950849431005822
# -----------------------------------------------------------
# Validation loss decreased (1.095531 --> 1.095085).  Saving model ...
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 55.264275550842285s | valid accuracy 0.3670299206576809 | valid loss 1.0946533338374684
# -----------------------------------------------------------
# Validation loss decreased (1.095085 --> 1.094653).  Saving model ...
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 55.11590886116028s | valid accuracy 0.3669056495554918 | valid loss 1.0942399088942676
# -----------------------------------------------------------
# Validation loss decreased (1.094653 --> 1.094240).  Saving model ...
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 55.09276103973389s | valid accuracy 0.36764171685307334 | valid loss 1.0938487057292132
# -----------------------------------------------------------
# Validation loss decreased (1.094240 --> 1.093849).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 12 | time: 55.51484155654907s | valid accuracy 0.3691616480260013 | valid loss 1.0934833694853185
# -----------------------------------------------------------
# Validation loss decreased (1.093849 --> 1.093483).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 13 | time: 55.25837302207947s | valid accuracy 0.37290889972277985 | valid loss 1.0931461454713745
# -----------------------------------------------------------
# Validation loss decreased (1.093483 --> 1.093146).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 14 | time: 55.20703911781311s | valid accuracy 0.3748207628333811 | valid loss 1.0928397122326248
# -----------------------------------------------------------
# Validation loss decreased (1.093146 --> 1.092840).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 15 | time: 54.88210678100586s | valid accuracy 0.3778606251792372 | valid loss 1.0925662157550136
# -----------------------------------------------------------
# Validation loss decreased (1.092840 --> 1.092566).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 16 | time: 54.968504905700684s | valid accuracy 0.3780804894369563 | valid loss 1.0923273621166882
# -----------------------------------------------------------
# Validation loss decreased (1.092566 --> 1.092327).  Saving model ...
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 17 | time: 55.06486964225769s | valid accuracy 0.3774973711882229 | valid loss 1.0921244512639643
# -----------------------------------------------------------
# Validation loss decreased (1.092327 --> 1.092124).  Saving model ...
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 18 | time: 55.1880886554718s | valid accuracy 0.37740177803269287 | valid loss 1.091958777820663
# -----------------------------------------------------------
# Validation loss decreased (1.092124 --> 1.091959).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 19 | time: 54.81002759933472s | valid accuracy 0.3854124844661122 | valid loss 1.0918306191397733
# -----------------------------------------------------------
# Validation loss decreased (1.091959 --> 1.091831).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 20 | time: 55.290507793426514s | valid accuracy 0.392486377975337 | valid loss 1.0917395766175122
# -----------------------------------------------------------
# Validation loss decreased (1.091831 --> 1.091740).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 21 | time: 55.1103298664093s | valid accuracy 0.39323200458847146 | valid loss 1.0916855489806663
# -----------------------------------------------------------
# Validation loss decreased (1.091740 --> 1.091686).  Saving model ...
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 22 | time: 55.05476760864258s | valid accuracy 0.3904693623936526 | valid loss 1.0916681046515064
# -----------------------------------------------------------
# Validation loss decreased (1.091686 --> 1.091668).  Saving model ...
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 23 | time: 55.00220274925232s | valid accuracy 0.3846381799063187 | valid loss 1.0916864617155233
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 3
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 24 | time: 55.33887481689453s | valid accuracy 0.3763789312685212 | valid loss 1.0917392590541724
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 3
# 9.75528258147577e-05
# Adjusting learning rate of group 0 to 9.7044e-05.
# -----------------------------------------------------------
# | end of epoch 25 | time: 54.90804743766785s | valid accuracy 0.3737023229136794 | valid loss 1.0918247888212176
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 3
# Early stopping
# tensor(0.3739, device='cuda:0')

# %%
wandb.init(project='result', entity='gyeongmoCho',name='Bilstm')
wandb.log({'final_f1_score':score})
# Out:
# wandb: Currently logged in as: gyeongmocho. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/jbj4278/wandb/run-20220607_071658-2r3jn2x3</code>
# Syncing run <strong><a href="https://wandb.ai/gyeongmocho/result/runs/2r3jn2x3" target="_blank">Bilstm</a></strong> to <a href="https://wandb.ai/gyeongmocho/result" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# ### 예측 라벨 붙여주기

# %%
pred_label = list(map(list, label))

answer = sum(pred_label, [])

final_label = []
for i in answer:
    final_label.append(i.tolist())

# %% [markdown]
# #### voting을 위한 확률값 생성

# %%
def make_result(model,test_dataloader):
    model.eval()
    pred_soft = []
    pred_hard=[]
    
    correct_count, all_count = 0,0
    with torch.no_grad():
        for idx, (feature, label) in enumerate(test_dataloader):
            if torch.cuda.is_available():
                feature, labels = feature.to(device),label.to(device)
            for i in range(len(labels)):
                #soft
                predicted_label = model(feature.to(device))
                sm = nn.Softmax(dim=1)
                probabilities = sm(predicted_label)
                prob_arr = (probabilities.detach().cpu().numpy())[0]
                pred_soft.append(prob_arr)
                #hard
                logps = model(feature.to(device))
                ps = torch.exp(logps)
                probab = list(ps.cpu()[0])
                pred_label = probab.index(max(probab))
                true_label = labels.cpu()[i]
                pred_hard.append(pred_label)
                if(true_label == pred_label):
                    correct_count += 1
                all_count += 1
                
                
    return pred_soft ,pred_hard

# %%
soft, hard = make_result(model,test_dataloader)

# %%
soft = pd.DataFrame(soft)

# %%
final_labels = pd.DataFrame(final_label,columns = ['pred_labels'])

test_set = test_set[:-10]

index = final_labels.index

test_set.index = index

plus_label_df = test_set.join(final_labels['pred_labels'],how='right') 

plus_label_df = plus_label_df.join(soft,how='right')

# %%
plus_label_df.to_csv('final_BiLSTM_label.csv')

# %%
plus_label_df
# Out:
#                        Date     Open     High      Low    Close     Volume  \
# 0       2022-01-09 20:55:00  3934000  3934000  3931000  3933000   7.091395
# 1       2022-01-09 20:56:00  3933000  3935000  3931000  3932000  14.144101
# 2       2022-01-09 20:57:00  3932000  3934000  3930000  3933000  19.051929
# 3       2022-01-09 20:58:00  3933000  3935000  3930000  3935000  11.908381
# 4       2022-01-09 20:59:00  3935000  3936000  3934000  3935000   7.690722
# ...                     ...      ...      ...      ...      ...        ...
# 104605  2022-03-23 15:05:00  3662000  3664000  3660000  3662000  29.579468
# 104606  2022-03-23 15:06:00  3662000  3666000  3661000  3664000  31.708145
# 104607  2022-03-23 15:07:00  3665000  3669000  3664000  3666000  42.205886
# 104608  2022-03-23 15:08:00  3664000  3666000  3663000  3665000  20.221637
# 104609  2022-03-23 15:09:00  3666000  3666000  3664000  3664000  34.800540
#
#          BTC_close     DXY       BTCD  Kimchi_premium   S&P500  Ethereum DeFi  \
# 0       52343000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 1       52315000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 2       52313000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 3       52313000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 4       52292000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# ...            ...     ...        ...             ...      ...            ...
# 104605  51697000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 104606  51710000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 104607  51745000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 104608  51731000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 104609  51744000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
#
#         News_freq  signal  pred_labels         0         1         2
# 0            26.0     1.0            1  0.267247  0.387458  0.345295
# 1            26.0     1.0            1  0.267247  0.387458  0.345295
# 2            26.0     1.0            1  0.267247  0.387458  0.345295
# 3            26.0     1.0            1  0.267247  0.387458  0.345295
# 4            26.0     1.0            1  0.267247  0.387458  0.345295
# ...           ...     ...          ...       ...       ...       ...
# 104605       57.0     2.0            2  0.308950  0.347495  0.343555
# 104606       57.0     2.0            2  0.308950  0.347495  0.343555
# 104607       57.0     2.0            2  0.308950  0.347495  0.343555
# 104608       57.0     2.0            2  0.322463  0.332964  0.344573
# 104609       57.0     2.0            2  0.322463  0.332964  0.344573
#
# [104610 rows x 18 columns]

# %%
plus_label_df['pred_labels'].value_counts()
# Out:
# 2    43450
# 0    39715
# 1    21445
# Name: pred_labels, dtype: int64
