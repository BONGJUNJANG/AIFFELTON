# %% [markdown]
# # 1DCNN + LSTM 결합 model

# %%
import pandas as pd 
import pandas_datareader as pdr   
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
import random
import os
import torch
random.seed(123)
np.random.seed(123)
os.environ["PYTHONHASHSEED"] = str(123)
torch.manual_seed(123)
torch.cuda.manual_seed(123)               # type: ignore
torch.backends.cudnn.deterministic = True  # type: ignore
torch.backends.cudnn.benchmark = True      # type: ignore

# %% [markdown]
# ## 1. 데이터 로드 및 전처리

# %%
final = pd.read_csv('/home/jbj4278/ETH_data/final_dateadd') #feature포함 데이터

# %%
col = ['Date','Open', 'High', 'Low', 'Close', 'Volume','BTC_close', 'DXY', 'BTCD', 'Kimchi_premium', 'S&P500', 'Ethereum DeFi',
   'News_freq','signal']

# %%
final = final.loc[:,col]

# %%
final.loc[final['signal']==0.0 , "signal"] = 2   # 보합 > 2로
final.loc[final['signal']==1.0 , "signal"] = 0  
 # 상승 > 0으로
final.loc[final['signal']==-1.0 , "signal"] = 1 #하락 > 1로
#(상승, 하락, 보합) > (0 ,1, 2)

# %%
final['signal'].value_counts()
# Out:
# 0.0    188025
# 1.0    171867
# 2.0    163209
# Name: signal, dtype: int64

# %% [markdown]
# #### 시계열의 연속성을 고려하기 위해 window_size를 설정하여 data를 3차원으로 변경하는 함수

# %%
def make_dataset(data, label, window_size):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
window_size = 10

# %%
final.shape
# Out:
# (523101, 14)

# %% [markdown]
# #### train+val/ test split

# %%
len_test = int(len(final)*0.2)
test_set = final[-len_test:]
tr_set = final[:-len_test]

# %%
test_set.shape
# Out:
# (104620, 14)

# %%
test_set
# Out:
#                        Date     Open     High      Low    Close     Volume  \
# 418481  2022-01-09 20:55:00  3934000  3934000  3931000  3933000   7.091395
# 418482  2022-01-09 20:56:00  3933000  3935000  3931000  3932000  14.144101
# 418483  2022-01-09 20:57:00  3932000  3934000  3930000  3933000  19.051929
# 418484  2022-01-09 20:58:00  3933000  3935000  3930000  3935000  11.908381
# 418485  2022-01-09 20:59:00  3935000  3936000  3934000  3935000   7.690722
# ...                     ...      ...      ...      ...      ...        ...
# 523096  2022-03-23 15:15:00  3666000  3667000  3665000  3665000  39.688187
# 523097  2022-03-23 15:16:00  3666000  3669000  3665000  3668000  76.731647
# 523098  2022-03-23 15:17:00  3668000  3671000  3667000  3669000  96.039465
# 523099  2022-03-23 15:18:00  3667000  3674000  3663000  3663000  91.949217
# 523100  2022-03-23 15:19:00  3663000  3663000  3660000  3662000  29.505753
#
#          BTC_close     DXY       BTCD  Kimchi_premium   S&P500  Ethereum DeFi  \
# 418481  52343000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 418482  52315000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 418483  52313000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 418484  52313000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# 418485  52292000.0  95.739  40.435605       -12.94548  4677.04   1.401528e+11
# ...            ...     ...        ...             ...      ...            ...
# 523096  51801000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 523097  51753000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 523098  51782000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 523099  51780000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
# 523100  51728000.0  98.793  42.584513        15.24980  4488.22   1.159212e+11
#
#         News_freq  signal
# 418481       26.0     1.0
# 418482       26.0     1.0
# 418483       26.0     1.0
# 418484       26.0     1.0
# 418485       26.0     1.0
# ...           ...     ...
# 523096       57.0     2.0
# 523097       57.0     2.0
# 523098       57.0     2.0
# 523099       57.0     2.0
# 523100       57.0     2.0
#
# [104620 rows x 14 columns]

# %%
tr_set.shape
# Out:
# (418481, 14)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torchmetrics.functional import f1_score,precision_recall
device = torch.device("cpu")
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import wandb
# !wandb login
# Out:
# wandb: Currently logged in as: gyeongmocho. Use `wandb login --relogin` to force relogin

# %%
import time

def train(dataloader):
 
    model.train()
    total_acc, total_count = 0, 0
    start_time = time.time()

    
    loss_list = []
    for idx, (feature, label) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(feature.to(device))
        loss = criterion(predicted_label, label.to(device))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        
        total_count += label.size(0)
        loss_list.append(loss.item())
        
        if idx+1 % len(feature) == 0 and idx > 0:
            accuracy = total_acc/total_count
            loss_hist = np.mean(loss_list)
            elapsed = time.time() - start_time
            print(f'| epoch {epoch} | {idx}/{len(dataloader)} batches '
                f'| accuracy {accuracy} | loss {loss_hist}')
            total_acc, total_count = 0, 0
            start_time = time.time()

    wandb.log({'train_loss':np.mean(loss_list),'train_acc':total_acc/total_count})  
    return  total_acc/total_count,np.mean(loss_list)
    
            

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    loss_list = []
    
    score,precision,recall = 0, 0, 0
    with torch.no_grad():
        for idx, (feature, label) in enumerate(dataloader):
            feature, label = feature.to(device),label.to(device)
            predicted_label = model(feature.to(device))
            loss = criterion(predicted_label, label.to(device))
            
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
            loss_list.append(loss.item())
            
            
            
            score += f1_score(predicted_label.argmax(1).to(device), label,num_classes=3)
            precision += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[0]
            recall += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[1]
      
        
        score = score / len(loss_list)
        precision = precision / len(loss_list)
        recall = recall / len(loss_list)
            
    #wandb.log({'val_loss':np.mean(loss_list), 'val_acc':total_acc/total_count,'f1_score':score,
              #'precision':precision,'recall':recall})
    
    return total_acc/total_count, np.mean(loss_list),score

# %%
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self,path, patience=10, verbose=False, delta=0,):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class BlockingTimeSeriesSplit():
    def __init__(self, n_splits):
        self.n_splits = n_splits
    
    def get_n_splits(self, groups):
        return self.n_splits
    
    def split(self, X, y=None, groups=None):
        n_samples = len(X)
        k_fold_size = n_samples // self.n_splits
        indices = np.arange(n_samples)
    
        margin = 0
        for i in range(self.n_splits):
            start = i * k_fold_size
            stop = start + k_fold_size
            mid = int(0.9 * (stop - start)) + start
            yield indices[start: mid], indices[mid + margin: stop]

# %% [markdown]
# ## 모델 정의

# %%
class Conv1dlstm(nn.Module):
    def __init__(self, in_channel=12, out_channels=6):
        super(Conv1dlstm, self).__init__()
        self.conv1d_1 = nn.Conv1d(in_channels=in_channel,
                                out_channels=out_channels,
                                kernel_size=6,
                                stride=1)
                                
        
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)

        self.lstm = nn.LSTM(input_size=6,
                            hidden_size=20,
                            num_layers=1,
                            batch_first = True
                            )
        

      
        self.dense = nn.Linear(20, 3)

    def forward(self, x):
	# Raw x shape : (B, S, F) => (B, 30, 33)
        
        # Shape : (B, F, S) => (B, 33, 30)
        x = x.transpose(1, 2)
        
        # Shape : (B, F, S) == (B, C, S) // C = channel => (B, 33, 21)
        x = self.conv1d_1(x)
        
        x = self.relu(x)
    

        # Shape : (B, 21, 33)
        x = x.transpose(2,1)

        
        
        # LSTM 순전파
        self.lstm.flatten_parameters()
        
        
        out, (hn, cn) = self.lstm(x) # out : (BATCH_SIZE, SEQ_LENGTH, HIDDEN_SIZE)  , hn이 lstm의 마지막 hidden state
       
        x = out[:, -1, :]
        

       
        
        # Shape : (B, H) => (B, 10)
        
        
        # Shape : (B, O) // O = output => (B, 3)
        x = self.dense(x)
        

        return x

# %%
lr = 0.0001
batch_size = 32

# %% [markdown]
# ## 모델 학습 (cross validation)

# %%
btss = BlockingTimeSeriesSplit(n_splits=5)
n_epochs = 150
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']
score_list = []
val_loss_list = []
voting_list = []
#cross validation

wandb.init(project='cnnlstm', entity='gyeongmoCho',name='cnnlstm_hidden4x_smallbatch_')
#wandb.watch(model, criterion, log = "all" )


for idx,(tr_idx, val_idx) in enumerate(btss.split(tr_set)):
    
    train_data, val_data = tr_set.iloc[tr_idx], tr_set.iloc[val_idx]
    
    
    scaler = StandardScaler()
    scaler.fit(train_data[scale_cols])#for문을 돌면서 각 train, val을 스케일링ㅇ
    train_feature = scaler.transform(train_data[scale_cols])
    train_feature = pd.DataFrame(train_feature)                                 
    val_feature = scaler.transform(val_data[scale_cols])
    val_feature = pd.DataFrame(val_feature)   

    
    train_feature, train_label = make_dataset(train_feature, train_data['signal'], window_size)
    val_feature, val_label = make_dataset(val_feature, val_data['signal'], window_size)

    
    #모델 선언 
    
    model = Conv1dlstm().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0,verbose=True)
    total_accu = None


    print(model)
    
    early_stopping = EarlyStopping(patience = 10, verbose = True)



    #스케일링된 데이터를 torch Tensor로 변경
    val_feature = torch.FloatTensor(val_feature).to(device)
    val_label = torch.LongTensor(val_label).to(device)
    train_feature = torch.FloatTensor(train_feature).to(device)
    train_label  = torch.LongTensor(train_label).to(device)

    train_set = TensorDataset(train_feature,train_label)
    val_set = TensorDataset(val_feature,val_label)
    
    #데이터로더 사용
    BATCH_SIZE = batch_size
    train_dataloader = DataLoader(train_set , batch_size=BATCH_SIZE,shuffle=False)
    valid_dataloader = DataLoader(val_set, batch_size=BATCH_SIZE,shuffle=False)

    print(f"train_feature:{train_feature.shape},val_feature:{val_feature.shape}" )
    

    for epoch in range(1, n_epochs + 1):
        # 현재 learning rate 출력
        print(optimizer.param_groups[0]['lr'])
        epoch_start_time = time.time()
        accu_train, train_loss = train(train_dataloader)
        accu_val,val_loss,score = evaluate(valid_dataloader)
        if total_accu is not None and total_accu > accu_val:
            scheduler.step()
        else:
            total_accu = accu_val
        print('-' * 59)
        print(f'| end of epoch {epoch} | time: {time.time()- epoch_start_time}s | '
            f'valid accuracy {accu_val} | valid loss {val_loss}'
            ) 

        print('-' * 59)
        
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    score_list.append(score)
    print("save score")

    
    PATH = f"/home/jbj4278/ETH_data/cnnlstm_hidden4x_smallbatch__{idx}.pt"
    torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),


                }, PATH)
    print('-' * 59)
    print('Fold Finish')
    print('-' * 59)

score_list = list(map(float, score_list))
final_f1_score = np.mean(score_list)
print(final_f1_score)
wandb.log({'mean_f1_score':final_f1_score})
# Out:
# Finishing last run (ID:290ufqbf) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">cnnlstm_hidden4x_smallbatch_</strong>: <a href="https://wandb.ai/gyeongmocho/cnnlstm/runs/290ufqbf" target="_blank">https://wandb.ai/gyeongmocho/cnnlstm/runs/290ufqbf</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220605_131446-290ufqbf/logs</code>
# Successfully finished last run (ID:290ufqbf). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/jbj4278/wandb/run-20220605_131534-1dxsbpif</code>
# Syncing run <strong><a href="https://wandb.ai/gyeongmocho/cnnlstm/runs/1dxsbpif" target="_blank">cnnlstm_hidden4x_smallbatch_</a></strong> to <a href="https://wandb.ai/gyeongmocho/cnnlstm" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Adjusting learning rate of group 0 to 1.0000e-04.
# Conv1dlstm(
#   (conv1d_1): Conv1d(12, 12, kernel_size=(6,), stride=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(12, 40, batch_first=True)
#   (dense): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 7.4588422775268555s | valid accuracy 0.29832535885167466 | valid loss 1.1203265563222289
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.120327).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 7.566527366638184s | valid accuracy 0.32057416267942584 | valid loss 1.129225084572348
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 7.616450786590576s | valid accuracy 0.2604066985645933 | valid loss 1.1382876796121815
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 7.542437314987183s | valid accuracy 0.23660287081339712 | valid loss 1.147463022525074
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 7.493598222732544s | valid accuracy 0.2355263157894737 | valid loss 1.1567039792319291
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 7.62054967880249s | valid accuracy 0.23313397129186603 | valid loss 1.165958947125282
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 7 | time: 7.513508558273315s | valid accuracy 0.2299043062200957 | valid loss 1.1751854310508902
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 7.491061687469482s | valid accuracy 0.2291866028708134 | valid loss 1.184343751150233
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 7.4515380859375s | valid accuracy 0.22882775119617224 | valid loss 1.1934010670840285
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 7.553986310958862s | valid accuracy 0.22882775119617224 | valid loss 1.2023233434626164
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 7.7302985191345215s | valid accuracy 0.22882775119617224 | valid loss 1.2110832338114732
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# Conv1dlstm(
#   (conv1d_1): Conv1d(12, 12, kernel_size=(6,), stride=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(12, 40, batch_first=True)
#   (dense): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 7.451383113861084s | valid accuracy 0.27392344497607657 | valid loss 1.1180739084272895
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.118074).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 7.52951192855835s | valid accuracy 0.27392344497607657 | valid loss 1.1138195586568527
# -----------------------------------------------------------
# Validation loss decreased (1.118074 --> 1.113820).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 3 | time: 7.576850414276123s | valid accuracy 0.27392344497607657 | valid loss 1.10994958286067
# -----------------------------------------------------------
# Validation loss decreased (1.113820 --> 1.109950).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 4 | time: 7.525311470031738s | valid accuracy 0.27392344497607657 | valid loss 1.106423526774836
# -----------------------------------------------------------
# Validation loss decreased (1.109950 --> 1.106424).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 5 | time: 7.5283520221710205s | valid accuracy 0.27392344497607657 | valid loss 1.10321298628363
# -----------------------------------------------------------
# Validation loss decreased (1.106424 --> 1.103213).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 6 | time: 7.454718112945557s | valid accuracy 0.27392344497607657 | valid loss 1.1002852024922845
# -----------------------------------------------------------
# Validation loss decreased (1.103213 --> 1.100285).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 7 | time: 7.5004563331604s | valid accuracy 0.27392344497607657 | valid loss 1.0976079606827889
# -----------------------------------------------------------
# Validation loss decreased (1.100285 --> 1.097608).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 8 | time: 7.655866384506226s | valid accuracy 0.27392344497607657 | valid loss 1.0951544624248535
# -----------------------------------------------------------
# Validation loss decreased (1.097608 --> 1.095154).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 9 | time: 7.597190856933594s | valid accuracy 0.27392344497607657 | valid loss 1.0929060846794652
# -----------------------------------------------------------
# Validation loss decreased (1.095154 --> 1.092906).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 10 | time: 7.495355129241943s | valid accuracy 0.2797846889952153 | valid loss 1.0908411604757526
# -----------------------------------------------------------
# Validation loss decreased (1.092906 --> 1.090841).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 11 | time: 7.459832191467285s | valid accuracy 0.387799043062201 | valid loss 1.08893893966238
# -----------------------------------------------------------
# Validation loss decreased (1.090841 --> 1.088939).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 12 | time: 7.541598320007324s | valid accuracy 0.46375598086124403 | valid loss 1.0871902549539814
# -----------------------------------------------------------
# Validation loss decreased (1.088939 --> 1.087190).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 13 | time: 7.54605770111084s | valid accuracy 0.47081339712918663 | valid loss 1.085580562362234
# -----------------------------------------------------------
# Validation loss decreased (1.087190 --> 1.085581).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 14 | time: 7.569854736328125s | valid accuracy 0.4717703349282297 | valid loss 1.084099128501106
# -----------------------------------------------------------
# Validation loss decreased (1.085581 --> 1.084099).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 15 | time: 7.528924942016602s | valid accuracy 0.47165071770334926 | valid loss 1.0827377502244848
# -----------------------------------------------------------
# Validation loss decreased (1.084099 --> 1.082738).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 16 | time: 7.630408525466919s | valid accuracy 0.4717703349282297 | valid loss 1.0814843054946142
# -----------------------------------------------------------
# Validation loss decreased (1.082738 --> 1.081484).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 17 | time: 7.504762887954712s | valid accuracy 0.4717703349282297 | valid loss 1.0803282825091414
# -----------------------------------------------------------
# Validation loss decreased (1.081484 --> 1.080328).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 18 | time: 7.484419107437134s | valid accuracy 0.4717703349282297 | valid loss 1.079260569037372
# -----------------------------------------------------------
# Validation loss decreased (1.080328 --> 1.079261).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 19 | time: 7.579334259033203s | valid accuracy 0.4717703349282297 | valid loss 1.078276449942407
# -----------------------------------------------------------
# Validation loss decreased (1.079261 --> 1.078276).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 20 | time: 7.491960048675537s | valid accuracy 0.4717703349282297 | valid loss 1.0773646920236923
# -----------------------------------------------------------
# Validation loss decreased (1.078276 --> 1.077365).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 21 | time: 7.606255054473877s | valid accuracy 0.4717703349282297 | valid loss 1.0765243036146381
# -----------------------------------------------------------
# Validation loss decreased (1.077365 --> 1.076524).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 22 | time: 7.567018032073975s | valid accuracy 0.4717703349282297 | valid loss 1.075750899223881
# -----------------------------------------------------------
# Validation loss decreased (1.076524 --> 1.075751).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 23 | time: 7.584665060043335s | valid accuracy 0.4717703349282297 | valid loss 1.0750389221970362
# -----------------------------------------------------------
# Validation loss decreased (1.075751 --> 1.075039).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 24 | time: 7.522465705871582s | valid accuracy 0.4717703349282297 | valid loss 1.0743833002243333
# -----------------------------------------------------------
# Validation loss decreased (1.075039 --> 1.074383).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 25 | time: 7.5411293506622314s | valid accuracy 0.4717703349282297 | valid loss 1.0737803944649587
# -----------------------------------------------------------
# Validation loss decreased (1.074383 --> 1.073780).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 26 | time: 7.562072992324829s | valid accuracy 0.4717703349282297 | valid loss 1.0732267214596727
# -----------------------------------------------------------
# Validation loss decreased (1.073780 --> 1.073227).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 27 | time: 7.567407608032227s | valid accuracy 0.4717703349282297 | valid loss 1.0727167011217307
# -----------------------------------------------------------
# Validation loss decreased (1.073227 --> 1.072717).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 28 | time: 7.521416902542114s | valid accuracy 0.4717703349282297 | valid loss 1.0722530395475052
# -----------------------------------------------------------
# Validation loss decreased (1.072717 --> 1.072253).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 29 | time: 7.499380111694336s | valid accuracy 0.4717703349282297 | valid loss 1.071827455331351
# -----------------------------------------------------------
# Validation loss decreased (1.072253 --> 1.071827).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 30 | time: 7.550926446914673s | valid accuracy 0.4717703349282297 | valid loss 1.0714425317203726
# -----------------------------------------------------------
# Validation loss decreased (1.071827 --> 1.071443).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 31 | time: 7.5018229484558105s | valid accuracy 0.4717703349282297 | valid loss 1.0710942403960775
# -----------------------------------------------------------
# Validation loss decreased (1.071443 --> 1.071094).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 32 | time: 7.492541313171387s | valid accuracy 0.4717703349282297 | valid loss 1.0707790103122479
# -----------------------------------------------------------
# Validation loss decreased (1.071094 --> 1.070779).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 33 | time: 7.518957853317261s | valid accuracy 0.4717703349282297 | valid loss 1.0704960768459408
# -----------------------------------------------------------
# Validation loss decreased (1.070779 --> 1.070496).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 34 | time: 7.548527002334595s | valid accuracy 0.4717703349282297 | valid loss 1.0702427282133176
# -----------------------------------------------------------
# Validation loss decreased (1.070496 --> 1.070243).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 35 | time: 7.567062854766846s | valid accuracy 0.4717703349282297 | valid loss 1.070018062382254
# -----------------------------------------------------------
# Validation loss decreased (1.070243 --> 1.070018).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 36 | time: 7.5298171043396s | valid accuracy 0.4717703349282297 | valid loss 1.0698197324767367
# -----------------------------------------------------------
# Validation loss decreased (1.070018 --> 1.069820).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 37 | time: 7.514203786849976s | valid accuracy 0.4717703349282297 | valid loss 1.0696464535844235
# -----------------------------------------------------------
# Validation loss decreased (1.069820 --> 1.069646).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 38 | time: 7.532097101211548s | valid accuracy 0.4717703349282297 | valid loss 1.0694962225797522
# -----------------------------------------------------------
# Validation loss decreased (1.069646 --> 1.069496).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 39 | time: 7.646445274353027s | valid accuracy 0.4717703349282297 | valid loss 1.0693671937662226
# -----------------------------------------------------------
# Validation loss decreased (1.069496 --> 1.069367).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 40 | time: 7.595901966094971s | valid accuracy 0.4717703349282297 | valid loss 1.0692603164956769
# -----------------------------------------------------------
# Validation loss decreased (1.069367 --> 1.069260).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 41 | time: 7.588608264923096s | valid accuracy 0.4717703349282297 | valid loss 1.0691732002123622
# -----------------------------------------------------------
# Validation loss decreased (1.069260 --> 1.069173).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 42 | time: 7.5973756313323975s | valid accuracy 0.4717703349282297 | valid loss 1.0691032143494554
# -----------------------------------------------------------
# Validation loss decreased (1.069173 --> 1.069103).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 43 | time: 7.617692708969116s | valid accuracy 0.4717703349282297 | valid loss 1.0690521652461917
# -----------------------------------------------------------
# Validation loss decreased (1.069103 --> 1.069052).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 44 | time: 7.547760248184204s | valid accuracy 0.4717703349282297 | valid loss 1.069019363126682
# -----------------------------------------------------------
# Validation loss decreased (1.069052 --> 1.069019).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 45 | time: 7.5005505084991455s | valid accuracy 0.4717703349282297 | valid loss 1.0690045334000624
# -----------------------------------------------------------
# Validation loss decreased (1.069019 --> 1.069005).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 46 | time: 7.659649610519409s | valid accuracy 0.4717703349282297 | valid loss 1.069005384017493
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 47 | time: 7.509401321411133s | valid accuracy 0.4717703349282297 | valid loss 1.0690239843066411
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 48 | time: 7.562524795532227s | valid accuracy 0.4717703349282297 | valid loss 1.0690614535608365
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 49 | time: 7.516176462173462s | valid accuracy 0.4717703349282297 | valid loss 1.0691154517290247
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 50 | time: 7.672767639160156s | valid accuracy 0.4717703349282297 | valid loss 1.0691850936139813
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 51 | time: 7.503865003585815s | valid accuracy 0.4717703349282297 | valid loss 1.0692718977691562
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 52 | time: 7.5518574714660645s | valid accuracy 0.4717703349282297 | valid loss 1.0693756876556018
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 53 | time: 7.584511756896973s | valid accuracy 0.4717703349282297 | valid loss 1.0694966571021627
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 54 | time: 7.590255975723267s | valid accuracy 0.4717703349282297 | valid loss 1.0696361993105357
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 55 | time: 7.490796327590942s | valid accuracy 0.4717703349282297 | valid loss 1.0697921591860649
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# Conv1dlstm(
#   (conv1d_1): Conv1d(12, 12, kernel_size=(6,), stride=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(12, 40, batch_first=True)
#   (dense): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 7.543515682220459s | valid accuracy 0.34904306220095693 | valid loss 1.0977392929200909
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.097739).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 2 | time: 7.558823823928833s | valid accuracy 0.33624401913875596 | valid loss 1.0984971632484262
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 7.653040170669556s | valid accuracy 0.3026315789473684 | valid loss 1.099328834591931
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 7.45932149887085s | valid accuracy 0.3070574162679426 | valid loss 1.1002136741885702
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 5 | time: 7.602672338485718s | valid accuracy 0.3046650717703349 | valid loss 1.1011333183477854
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 7.58230996131897s | valid accuracy 0.3033492822966507 | valid loss 1.1020727330491742
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 7 | time: 7.663941144943237s | valid accuracy 0.30239234449760766 | valid loss 1.1030194854918327
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 8 | time: 7.61722993850708s | valid accuracy 0.30358851674641146 | valid loss 1.103963937013204
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 7.511639833450317s | valid accuracy 0.3043062200956938 | valid loss 1.1048969735626046
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 7.539645195007324s | valid accuracy 0.3041866028708134 | valid loss 1.1058103014494627
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 7.5601770877838135s | valid accuracy 0.30406698564593304 | valid loss 1.1066987682844847
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# Conv1dlstm(
#   (conv1d_1): Conv1d(12, 12, kernel_size=(6,), stride=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(12, 40, batch_first=True)
#   (dense): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 7.5727455615997314s | valid accuracy 0.18791866028708135 | valid loss 1.12556738616856
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.125567).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 7.969406366348267s | valid accuracy 0.19138755980861244 | valid loss 1.1224057073811537
# -----------------------------------------------------------
# Validation loss decreased (1.125567 --> 1.122406).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 3 | time: 7.547641277313232s | valid accuracy 0.18660287081339713 | valid loss 1.11943627177304
# -----------------------------------------------------------
# Validation loss decreased (1.122406 --> 1.119436).  Saving model ...
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 4 | time: 7.621833324432373s | valid accuracy 0.18767942583732058 | valid loss 1.1166409986619732
# -----------------------------------------------------------
# Validation loss decreased (1.119436 --> 1.116641).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 5 | time: 7.484308481216431s | valid accuracy 0.22045454545454546 | valid loss 1.1140157375626891
# -----------------------------------------------------------
# Validation loss decreased (1.116641 --> 1.114016).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 6 | time: 7.552625417709351s | valid accuracy 0.23504784688995214 | valid loss 1.111552247109304
# -----------------------------------------------------------
# Validation loss decreased (1.114016 --> 1.111552).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 7 | time: 7.531330823898315s | valid accuracy 0.2555023923444976 | valid loss 1.1092374811645682
# -----------------------------------------------------------
# Validation loss decreased (1.111552 --> 1.109237).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 8 | time: 7.455435276031494s | valid accuracy 0.28791866028708135 | valid loss 1.1070706289233143
# -----------------------------------------------------------
# Validation loss decreased (1.109237 --> 1.107071).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 9 | time: 7.467540264129639s | valid accuracy 0.3154306220095694 | valid loss 1.1050422296269249
# -----------------------------------------------------------
# Validation loss decreased (1.107071 --> 1.105042).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 10 | time: 7.454046964645386s | valid accuracy 0.3448564593301435 | valid loss 1.103142226925333
# -----------------------------------------------------------
# Validation loss decreased (1.105042 --> 1.103142).  Saving model ...
# 9.990133642141359e-05
# -----------------------------------------------------------
# | end of epoch 11 | time: 7.49562668800354s | valid accuracy 0.35454545454545455 | valid loss 1.1013565190875803
# -----------------------------------------------------------
# Validation loss decreased (1.103142 --> 1.101357).  Saving model ...
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 12 | time: 7.488686800003052s | valid accuracy 0.3519138755980861 | valid loss 1.099680951988424
# -----------------------------------------------------------
# Validation loss decreased (1.101357 --> 1.099681).  Saving model ...
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 13 | time: 7.462077379226685s | valid accuracy 0.33875598086124403 | valid loss 1.0981122123376104
# -----------------------------------------------------------
# Validation loss decreased (1.099681 --> 1.098112).  Saving model ...
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 14 | time: 7.438765525817871s | valid accuracy 0.3334928229665072 | valid loss 1.0966433009118524
# -----------------------------------------------------------
# Validation loss decreased (1.098112 --> 1.096643).  Saving model ...
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 15 | time: 7.534229516983032s | valid accuracy 0.32595693779904306 | valid loss 1.0952652556295612
# -----------------------------------------------------------
# Validation loss decreased (1.096643 --> 1.095265).  Saving model ...
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 16 | time: 7.516243934631348s | valid accuracy 0.33169856459330144 | valid loss 1.09397080881905
# -----------------------------------------------------------
# Validation loss decreased (1.095265 --> 1.093971).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 17 | time: 7.447510242462158s | valid accuracy 0.3588516746411483 | valid loss 1.0927571426821119
# -----------------------------------------------------------
# Validation loss decreased (1.093971 --> 1.092757).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 18 | time: 7.39812159538269s | valid accuracy 0.39677033492822966 | valid loss 1.0916117102135228
# -----------------------------------------------------------
# Validation loss decreased (1.092757 --> 1.091612).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 19 | time: 7.478820085525513s | valid accuracy 0.4267942583732057 | valid loss 1.0905331709912716
# -----------------------------------------------------------
# Validation loss decreased (1.091612 --> 1.090533).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 20 | time: 7.508183479309082s | valid accuracy 0.4527511961722488 | valid loss 1.089517003252306
# -----------------------------------------------------------
# Validation loss decreased (1.090533 --> 1.089517).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 21 | time: 7.4942708015441895s | valid accuracy 0.47452153110047846 | valid loss 1.0885606908616219
# -----------------------------------------------------------
# Validation loss decreased (1.089517 --> 1.088561).  Saving model ...
# 9.879583809693738e-05
# -----------------------------------------------------------
# | end of epoch 22 | time: 7.39861273765564s | valid accuracy 0.4842105263157895 | valid loss 1.0876586660174012
# -----------------------------------------------------------
# Validation loss decreased (1.088561 --> 1.087659).  Saving model ...
# 9.879583809693738e-05
# Adjusting learning rate of group 0 to 9.8429e-05.
# -----------------------------------------------------------
# | end of epoch 23 | time: 7.544625759124756s | valid accuracy 0.4717703349282297 | valid loss 1.0868065957804673
# -----------------------------------------------------------
# Validation loss decreased (1.087659 --> 1.086807).  Saving model ...
# 9.842915805643157e-05
# Adjusting learning rate of group 0 to 9.8015e-05.
# -----------------------------------------------------------
# | end of epoch 24 | time: 7.5161683559417725s | valid accuracy 0.4482057416267943 | valid loss 1.0860038458845997
# -----------------------------------------------------------
# Validation loss decreased (1.086807 --> 1.086004).  Saving model ...
# 9.801468428384717e-05
# Adjusting learning rate of group 0 to 9.7553e-05.
# -----------------------------------------------------------
# | end of epoch 25 | time: 7.540615081787109s | valid accuracy 0.43863636363636366 | valid loss 1.085248021224073
# -----------------------------------------------------------
# Validation loss decreased (1.086004 --> 1.085248).  Saving model ...
# 9.75528258147577e-05
# Adjusting learning rate of group 0 to 9.7044e-05.
# -----------------------------------------------------------
# | end of epoch 26 | time: 7.564768552780151s | valid accuracy 0.45502392344497605 | valid loss 1.084535434273363
# -----------------------------------------------------------
# Validation loss decreased (1.085248 --> 1.084535).  Saving model ...
# 9.70440384477113e-05
# Adjusting learning rate of group 0 to 9.6489e-05.
# -----------------------------------------------------------
# | end of epoch 27 | time: 7.484525918960571s | valid accuracy 0.46543062200956936 | valid loss 1.0838638892155568
# -----------------------------------------------------------
# Validation loss decreased (1.084535 --> 1.083864).  Saving model ...
# 9.64888242944126e-05
# Adjusting learning rate of group 0 to 9.5888e-05.
# -----------------------------------------------------------
# | end of epoch 28 | time: 7.531326532363892s | valid accuracy 0.4666267942583732 | valid loss 1.0832296625803446
# -----------------------------------------------------------
# Validation loss decreased (1.083864 --> 1.083230).  Saving model ...
# 9.588773128419907e-05
# Adjusting learning rate of group 0 to 9.5241e-05.
# -----------------------------------------------------------
# | end of epoch 29 | time: 7.564920663833618s | valid accuracy 0.466866028708134 | valid loss 1.0826321059965904
# -----------------------------------------------------------
# Validation loss decreased (1.083230 --> 1.082632).  Saving model ...
# 9.5241352623301e-05
# Adjusting learning rate of group 0 to 9.4550e-05.
# -----------------------------------------------------------
# | end of epoch 30 | time: 7.4747724533081055s | valid accuracy 0.4666267942583732 | valid loss 1.0820701047209382
# -----------------------------------------------------------
# Validation loss decreased (1.082632 --> 1.082070).  Saving model ...
# 9.455032620941843e-05
# Adjusting learning rate of group 0 to 9.3815e-05.
# -----------------------------------------------------------
# | end of epoch 31 | time: 7.570836544036865s | valid accuracy 0.4666267942583732 | valid loss 1.0815409972467496
# -----------------------------------------------------------
# Validation loss decreased (1.082070 --> 1.081541).  Saving model ...
# 9.381533400219321e-05
# Adjusting learning rate of group 0 to 9.3037e-05.
# -----------------------------------------------------------
# | end of epoch 32 | time: 7.537888288497925s | valid accuracy 0.4666267942583732 | valid loss 1.081044096983116
# -----------------------------------------------------------
# Validation loss decreased (1.081541 --> 1.081044).  Saving model ...
# 9.303710135019722e-05
# Adjusting learning rate of group 0 to 9.2216e-05.
# -----------------------------------------------------------
# | end of epoch 33 | time: 7.529363632202148s | valid accuracy 0.4666267942583732 | valid loss 1.0805755519229947
# -----------------------------------------------------------
# Validation loss decreased (1.081044 --> 1.080576).  Saving model ...
# 9.22163962751008e-05
# Adjusting learning rate of group 0 to 9.1354e-05.
# -----------------------------------------------------------
# | end of epoch 34 | time: 7.506006956100464s | valid accuracy 0.4666267942583732 | valid loss 1.0801375301284644
# -----------------------------------------------------------
# Validation loss decreased (1.080576 --> 1.080138).  Saving model ...
# 9.135402871372814e-05
# Adjusting learning rate of group 0 to 9.0451e-05.
# -----------------------------------------------------------
# | end of epoch 35 | time: 7.460412502288818s | valid accuracy 0.4666267942583732 | valid loss 1.0797255905984922
# -----------------------------------------------------------
# Validation loss decreased (1.080138 --> 1.079726).  Saving model ...
# 9.045084971874742e-05
# Adjusting learning rate of group 0 to 8.9508e-05.
# -----------------------------------------------------------
# | end of epoch 36 | time: 7.510861396789551s | valid accuracy 0.4666267942583732 | valid loss 1.07933773794247
# -----------------------------------------------------------
# Validation loss decreased (1.079726 --> 1.079338).  Saving model ...
# 8.950775061878456e-05
# Adjusting learning rate of group 0 to 8.8526e-05.
# -----------------------------------------------------------
# | end of epoch 37 | time: 7.55484414100647s | valid accuracy 0.4666267942583732 | valid loss 1.0789744562775123
# -----------------------------------------------------------
# Validation loss decreased (1.079338 --> 1.078974).  Saving model ...
# 8.852566213878951e-05
# Adjusting learning rate of group 0 to 8.7506e-05.
# -----------------------------------------------------------
# | end of epoch 38 | time: 7.546047925949097s | valid accuracy 0.4666267942583732 | valid loss 1.0786314358693043
# -----------------------------------------------------------
# Validation loss decreased (1.078974 --> 1.078631).  Saving model ...
# 8.750555348152303e-05
# Adjusting learning rate of group 0 to 8.6448e-05.
# -----------------------------------------------------------
# | end of epoch 39 | time: 7.489012956619263s | valid accuracy 0.4666267942583732 | valid loss 1.0783093523888188
# -----------------------------------------------------------
# Validation loss decreased (1.078631 --> 1.078309).  Saving model ...
# 8.644843137107063e-05
# Adjusting learning rate of group 0 to 8.5355e-05.
# -----------------------------------------------------------
# | end of epoch 40 | time: 7.460815668106079s | valid accuracy 0.4666267942583732 | valid loss 1.078005978169332
# -----------------------------------------------------------
# Validation loss decreased (1.078309 --> 1.078006).  Saving model ...
# 8.535533905932742e-05
# Adjusting learning rate of group 0 to 8.4227e-05.
# -----------------------------------------------------------
# | end of epoch 41 | time: 7.500079154968262s | valid accuracy 0.4666267942583732 | valid loss 1.0777207380942715
# -----------------------------------------------------------
# Validation loss decreased (1.078006 --> 1.077721).  Saving model ...
# 8.422735529643448e-05
# Adjusting learning rate of group 0 to 8.3066e-05.
# -----------------------------------------------------------
# | end of epoch 42 | time: 7.4901134967803955s | valid accuracy 0.4666267942583732 | valid loss 1.077452001453356
# -----------------------------------------------------------
# Validation loss decreased (1.077721 --> 1.077452).  Saving model ...
# 8.306559326618263e-05
# Adjusting learning rate of group 0 to 8.1871e-05.
# -----------------------------------------------------------
# | end of epoch 43 | time: 7.4212260246276855s | valid accuracy 0.4666267942583732 | valid loss 1.0771977314512238
# -----------------------------------------------------------
# Validation loss decreased (1.077452 --> 1.077198).  Saving model ...
# 8.187119948743452e-05
# Adjusting learning rate of group 0 to 8.0645e-05.
# -----------------------------------------------------------
# | end of epoch 44 | time: 7.5542311668396s | valid accuracy 0.4666267942583732 | valid loss 1.0769579235379023
# -----------------------------------------------------------
# Validation loss decreased (1.077198 --> 1.076958).  Saving model ...
# 8.064535268264887e-05
# Adjusting learning rate of group 0 to 7.9389e-05.
# -----------------------------------------------------------
# | end of epoch 45 | time: 7.485866546630859s | valid accuracy 0.4666267942583732 | valid loss 1.0767319034074099
# -----------------------------------------------------------
# Validation loss decreased (1.076958 --> 1.076732).  Saving model ...
# 7.938926261462371e-05
# Adjusting learning rate of group 0 to 7.8104e-05.
# -----------------------------------------------------------
# | end of epoch 46 | time: 7.47574520111084s | valid accuracy 0.4666267942583732 | valid loss 1.076520005255255
# -----------------------------------------------------------
# Validation loss decreased (1.076732 --> 1.076520).  Saving model ...
# 7.810416889260659e-05
# Adjusting learning rate of group 0 to 7.6791e-05.
# -----------------------------------------------------------
# | end of epoch 47 | time: 7.511563777923584s | valid accuracy 0.4666267942583732 | valid loss 1.0763216350824778
# -----------------------------------------------------------
# Validation loss decreased (1.076520 --> 1.076322).  Saving model ...
# 7.679133974894988e-05
# Adjusting learning rate of group 0 to 7.5452e-05.
# -----------------------------------------------------------
# | end of epoch 48 | time: 7.47390079498291s | valid accuracy 0.4666267942583732 | valid loss 1.076136281472126
# -----------------------------------------------------------
# Validation loss decreased (1.076322 --> 1.076136).  Saving model ...
# 7.545207078751862e-05
# Adjusting learning rate of group 0 to 7.4088e-05.
# -----------------------------------------------------------
# | end of epoch 49 | time: 7.524679183959961s | valid accuracy 0.4666267942583732 | valid loss 1.0759624604505438
# -----------------------------------------------------------
# Validation loss decreased (1.076136 --> 1.075962).  Saving model ...
# 7.408768370508582e-05
# Adjusting learning rate of group 0 to 7.2700e-05.
# -----------------------------------------------------------
# | end of epoch 50 | time: 7.536272764205933s | valid accuracy 0.4666267942583732 | valid loss 1.0758004573010307
# -----------------------------------------------------------
# Validation loss decreased (1.075962 --> 1.075800).  Saving model ...
# 7.26995249869774e-05
# Adjusting learning rate of group 0 to 7.1289e-05.
# -----------------------------------------------------------
# | end of epoch 51 | time: 7.4949870109558105s | valid accuracy 0.4665071770334928 | valid loss 1.0756488162597626
# -----------------------------------------------------------
# Validation loss decreased (1.075800 --> 1.075649).  Saving model ...
# 7.12889645782537e-05
# Adjusting learning rate of group 0 to 6.9857e-05.
# -----------------------------------------------------------
# | end of epoch 52 | time: 7.5563273429870605s | valid accuracy 0.46626794258373205 | valid loss 1.0755075982963767
# -----------------------------------------------------------
# Validation loss decreased (1.075649 --> 1.075508).  Saving model ...
# 6.985739453173908e-05
# Adjusting learning rate of group 0 to 6.8406e-05.
# -----------------------------------------------------------
# | end of epoch 53 | time: 7.462955951690674s | valid accuracy 0.4647129186602871 | valid loss 1.0753758811313687
# -----------------------------------------------------------
# Validation loss decreased (1.075508 --> 1.075376).  Saving model ...
# 6.840622763423397e-05
# Adjusting learning rate of group 0 to 6.6937e-05.
# -----------------------------------------------------------
# | end of epoch 54 | time: 7.450709819793701s | valid accuracy 0.46303827751196175 | valid loss 1.0752540606123802
# -----------------------------------------------------------
# Validation loss decreased (1.075376 --> 1.075254).  Saving model ...
# 6.693689601226464e-05
# Adjusting learning rate of group 0 to 6.5451e-05.
# -----------------------------------------------------------
# | end of epoch 55 | time: 7.552675247192383s | valid accuracy 0.46411483253588515 | valid loss 1.0751412226498582
# -----------------------------------------------------------
# Validation loss decreased (1.075254 --> 1.075141).  Saving model ...
# 6.545084971874744e-05
# Adjusting learning rate of group 0 to 6.3950e-05.
# -----------------------------------------------------------
# | end of epoch 56 | time: 7.4478654861450195s | valid accuracy 0.46351674641148327 | valid loss 1.075036639703139
# -----------------------------------------------------------
# Validation loss decreased (1.075141 --> 1.075037).  Saving model ...
# 6.394955530196154e-05
# Adjusting learning rate of group 0 to 6.2434e-05.
# -----------------------------------------------------------
# ...
# -----------------------------------------------------------
# Validation loss decreased (1.073963 --> 1.073963).  Saving model ...
# 6.962898649802823e-06
# Adjusting learning rate of group 0 to 6.1847e-06.
# -----------------------------------------------------------
# | end of epoch 99 | time: 7.544468641281128s | valid accuracy 0.3053827751196172 | valid loss 1.0739632660651024
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 6.184665997806831e-06
# Adjusting learning rate of group 0 to 5.4497e-06.
# -----------------------------------------------------------
# | end of epoch 100 | time: 7.41247034072876s | valid accuracy 0.30574162679425837 | valid loss 1.0739633031473814
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 5.449673790581619e-06
# Adjusting learning rate of group 0 to 4.7586e-06.
# -----------------------------------------------------------
# | end of epoch 101 | time: 7.470976114273071s | valid accuracy 0.305622009569378 | valid loss 1.0739633766294436
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 4.75864737669904e-06
# Adjusting learning rate of group 0 to 4.1123e-06.
# -----------------------------------------------------------
# | end of epoch 102 | time: 7.5040576457977295s | valid accuracy 0.305622009569378 | valid loss 1.0739634958387332
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 4.112268715800961e-06
# Adjusting learning rate of group 0 to 3.5112e-06.
# -----------------------------------------------------------
# | end of epoch 103 | time: 7.55254602432251s | valid accuracy 0.305622009569378 | valid loss 1.0739636312004264
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 3.5111757055874383e-06
# Adjusting learning rate of group 0 to 2.9560e-06.
# -----------------------------------------------------------
# | end of epoch 104 | time: 7.475842714309692s | valid accuracy 0.3055023923444976 | valid loss 1.0739637194699003
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 2.9559615522887324e-06
# Adjusting learning rate of group 0 to 2.4472e-06.
# -----------------------------------------------------------
# | end of epoch 105 | time: 7.501113414764404s | valid accuracy 0.305622009569378 | valid loss 1.073963820706797
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 2.4471741852423276e-06
# Adjusting learning rate of group 0 to 1.9853e-06.
# -----------------------------------------------------------
# | end of epoch 106 | time: 7.620755910873413s | valid accuracy 0.3055023923444976 | valid loss 1.073963891686374
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 1.9853157161528557e-06
# Adjusting learning rate of group 0 to 1.5708e-06.
# -----------------------------------------------------------
# | end of epoch 107 | time: 7.539979934692383s | valid accuracy 0.305622009569378 | valid loss 1.0739639037438022
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 1.5708419435684545e-06
# Adjusting learning rate of group 0 to 1.2042e-06.
# -----------------------------------------------------------
# | end of epoch 108 | time: 7.50184965133667s | valid accuracy 0.305622009569378 | valid loss 1.07396397290339
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-04.
# Conv1dlstm(
#   (conv1d_1): Conv1d(12, 12, kernel_size=(6,), stride=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(12, 40, batch_first=True)
#   (dense): Linear(in_features=40, out_features=3, bias=True)
# )
# train_feature:torch.Size([75316, 10, 12]),val_feature:torch.Size([8360, 10, 12])
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 7.478606462478638s | valid accuracy 0.47380382775119617 | valid loss 1.081319181746199
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.081319).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 7.592371940612793s | valid accuracy 0.4742822966507177 | valid loss 1.080344277711315
# -----------------------------------------------------------
# Validation loss decreased (1.081319 --> 1.080344).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 3 | time: 7.5555009841918945s | valid accuracy 0.4747607655502392 | valid loss 1.079443926347121
# -----------------------------------------------------------
# Validation loss decreased (1.080344 --> 1.079444).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 4 | time: 7.516641855239868s | valid accuracy 0.4759569377990431 | valid loss 1.0786118900957908
# -----------------------------------------------------------
# Validation loss decreased (1.079444 --> 1.078612).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 5 | time: 7.587606430053711s | valid accuracy 0.4767942583732057 | valid loss 1.0778458709935195
# -----------------------------------------------------------
# Validation loss decreased (1.078612 --> 1.077846).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 6 | time: 7.53950834274292s | valid accuracy 0.47655502392344495 | valid loss 1.0771399099408214
# -----------------------------------------------------------
# Validation loss decreased (1.077846 --> 1.077140).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 7 | time: 7.619979381561279s | valid accuracy 0.4771531100478469 | valid loss 1.0764914170931315
# -----------------------------------------------------------
# Validation loss decreased (1.077140 --> 1.076491).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 8 | time: 7.516529560089111s | valid accuracy 0.4777511961722488 | valid loss 1.0758969522159518
# -----------------------------------------------------------
# Validation loss decreased (1.076491 --> 1.075897).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 9 | time: 7.506654500961304s | valid accuracy 0.4779904306220096 | valid loss 1.0753534238302072
# -----------------------------------------------------------
# Validation loss decreased (1.075897 --> 1.075353).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 10 | time: 7.551324367523193s | valid accuracy 0.4779904306220096 | valid loss 1.074857590990212
# -----------------------------------------------------------
# Validation loss decreased (1.075353 --> 1.074858).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 11 | time: 7.58844518661499s | valid accuracy 0.4779904306220096 | valid loss 1.0744067996967839
# -----------------------------------------------------------
# Validation loss decreased (1.074858 --> 1.074407).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 12 | time: 7.646369934082031s | valid accuracy 0.47811004784688993 | valid loss 1.0739976285978128
# -----------------------------------------------------------
# Validation loss decreased (1.074407 --> 1.073998).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 13 | time: 7.566268682479858s | valid accuracy 0.47811004784688993 | valid loss 1.0736263972202331
# -----------------------------------------------------------
# Validation loss decreased (1.073998 --> 1.073626).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 14 | time: 7.421339511871338s | valid accuracy 0.47811004784688993 | valid loss 1.0732928459880917
# -----------------------------------------------------------
# Validation loss decreased (1.073626 --> 1.073293).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 15 | time: 7.3741936683654785s | valid accuracy 0.47811004784688993 | valid loss 1.0729919913160892
# -----------------------------------------------------------
# Validation loss decreased (1.073293 --> 1.072992).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 16 | time: 7.482198715209961s | valid accuracy 0.47811004784688993 | valid loss 1.0727224764023118
# -----------------------------------------------------------
# Validation loss decreased (1.072992 --> 1.072722).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 17 | time: 7.519386053085327s | valid accuracy 0.47811004784688993 | valid loss 1.0724819539157489
# -----------------------------------------------------------
# Validation loss decreased (1.072722 --> 1.072482).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 18 | time: 7.407891035079956s | valid accuracy 0.47811004784688993 | valid loss 1.0722688017910673
# -----------------------------------------------------------
# Validation loss decreased (1.072482 --> 1.072269).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 19 | time: 7.4514055252075195s | valid accuracy 0.47811004784688993 | valid loss 1.0720801367104509
# -----------------------------------------------------------
# Validation loss decreased (1.072269 --> 1.072080).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 20 | time: 7.413274765014648s | valid accuracy 0.47811004784688993 | valid loss 1.071916086755636
# -----------------------------------------------------------
# Validation loss decreased (1.072080 --> 1.071916).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 21 | time: 7.405548334121704s | valid accuracy 0.47811004784688993 | valid loss 1.0717759801231268
# -----------------------------------------------------------
# Validation loss decreased (1.071916 --> 1.071776).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 22 | time: 7.206836700439453s | valid accuracy 0.47811004784688993 | valid loss 1.0716596152491242
# -----------------------------------------------------------
# Validation loss decreased (1.071776 --> 1.071660).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 23 | time: 7.336364507675171s | valid accuracy 0.47811004784688993 | valid loss 1.0715667791948973
# -----------------------------------------------------------
# Validation loss decreased (1.071660 --> 1.071567).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 24 | time: 7.174754619598389s | valid accuracy 0.47811004784688993 | valid loss 1.071495804622883
# -----------------------------------------------------------
# Validation loss decreased (1.071567 --> 1.071496).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 25 | time: 7.403379917144775s | valid accuracy 0.47811004784688993 | valid loss 1.0714454739603378
# -----------------------------------------------------------
# Validation loss decreased (1.071496 --> 1.071445).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 26 | time: 7.3902318477630615s | valid accuracy 0.47811004784688993 | valid loss 1.0714149304473672
# -----------------------------------------------------------
# Validation loss decreased (1.071445 --> 1.071415).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 27 | time: 7.378155708312988s | valid accuracy 0.47811004784688993 | valid loss 1.0714018262979639
# -----------------------------------------------------------
# Validation loss decreased (1.071415 --> 1.071402).  Saving model ...
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 28 | time: 7.307977914810181s | valid accuracy 0.47811004784688993 | valid loss 1.071404886154728
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 29 | time: 7.3443732261657715s | valid accuracy 0.47811004784688993 | valid loss 1.071424197604638
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 30 | time: 7.306709051132202s | valid accuracy 0.47811004784688993 | valid loss 1.0714590042147019
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 31 | time: 7.215817928314209s | valid accuracy 0.47811004784688993 | valid loss 1.0715090814437576
# -----------------------------------------------------------
# EarlyStopping counter: 4 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 32 | time: 7.253680229187012s | valid accuracy 0.47811004784688993 | valid loss 1.0715733698306193
# -----------------------------------------------------------
# EarlyStopping counter: 5 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 33 | time: 7.201758861541748s | valid accuracy 0.47811004784688993 | valid loss 1.0716512228241404
# -----------------------------------------------------------
# EarlyStopping counter: 6 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 34 | time: 7.269453048706055s | valid accuracy 0.47811004784688993 | valid loss 1.0717428030858513
# -----------------------------------------------------------
# EarlyStopping counter: 7 out of 10
# 9.997532801828658e-05
# -----------------------------------------------------------
# | end of epoch 35 | time: 7.276117324829102s | valid accuracy 0.47811004784688993 | valid loss 1.0718470290871978
# -----------------------------------------------------------
# EarlyStopping counter: 8 out of 10
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 36 | time: 7.221388816833496s | valid accuracy 0.4779904306220096 | valid loss 1.0719645644417246
# -----------------------------------------------------------
# EarlyStopping counter: 9 out of 10
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 37 | time: 7.424550533294678s | valid accuracy 0.4779904306220096 | valid loss 1.072094414297861
# -----------------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early stopping
# save score
# -----------------------------------------------------------
# Fold Finish
# -----------------------------------------------------------
# 0.35834923684597014

# %% [markdown]
# ## f1-score의 fold별 평균이 가장 좋았던 모델로 Test set 성능 측정
# outchaanel = 6,hidden state = 20 , batch = 32, lr = 0.0001, mean_f1score = 0.3972

# %% [markdown]
# #### test_set dataloader 생성

# %%
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']
scaler = StandardScaler()
scaler.fit(tr_set[scale_cols])#for문을 돌면서 각 train, val을 스케일링
tr_feature = scaler.transform(tr_set[scale_cols])
tr_feature = pd.DataFrame(tr_feature)                                 
test_feature = scaler.transform(test_set[scale_cols])
test_feature = pd.DataFrame(test_feature)   


test_feature, test_label = make_dataset(test_feature, test_set['signal'], window_size)


#스케일링된 데이터를 torch Tensor로 변경
test_feature = torch.FloatTensor(test_feature).to(device)
test_label  = torch.LongTensor(test_label).to(device)

final_test_set = TensorDataset(test_feature,test_label)


#데이터로더 사용
BATCH_SIZE = 32
test_dataloader = DataLoader(final_test_set , batch_size=BATCH_SIZE,shuffle=False)

# %% [markdown]
# #### train_set dataloader 생성

# %%
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'BTC_close', 'DXY', 'BTCD',
       'Kimchi_premium', 'S&P500', 'Ethereum DeFi', 'News_freq']



   
scaler = StandardScaler()
scaler.fit(tr_set[scale_cols])#for문을 돌면서 각 train, val을 스케일링ㅇ
train_feature = scaler.transform(tr_set[scale_cols])
train_feature = pd.DataFrame(train_feature)                                 
 

    
train_feature, train_label = make_dataset(train_feature, tr_set['signal'], window_size)
  

train_feature = torch.FloatTensor(train_feature).to(device)
train_label  = torch.LongTensor(train_label).to(device)

train_set = TensorDataset(train_feature,train_label)


#데이터로더 사용
BATCH_SIZE = 32
final_dataloader = DataLoader(train_set , batch_size=BATCH_SIZE,shuffle=False)

# %%
#모델 저장 경로
path = f"/home/jbj4278/ETH_data/1DCNNLSTM_final_model.pt"

# %%
model = Conv1dlstm().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0,verbose=True)
total_accu = None
# Out:
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
import time

def train(dataloader):
 
    model.train()
    total_acc, total_count = 0, 0
    start_time = time.time()

    
    loss_list = []
    for idx, (feature, label) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(feature.to(device))
        loss = criterion(predicted_label, label.to(device))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        
        total_count += label.size(0)
        loss_list.append(loss.item())
        
        if idx+1 % len(feature) == 0 and idx > 0:
            accuracy = total_acc/total_count
            loss_hist = np.mean(loss_list)
            elapsed = time.time() - start_time
            print(f'| epoch {epoch} | {idx}/{len(dataloader)} batches '
                f'| accuracy {accuracy} | loss {loss_hist}')
            total_acc, total_count = 0, 0
            start_time = time.time()

      
    return  total_acc/total_count,np.mean(loss_list)
    
            

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    loss_list = []
    pred_label = []
    pred_prob = []
    score,precision,recall = 0, 0, 0
    with torch.no_grad():
        for idx, (feature, label) in enumerate(dataloader):
            feature, label = feature.to(device),label.to(device)
            predicted_label = model(feature.to(device))
            loss = criterion(predicted_label, label.to(device))
            
            
            sm = nn.Softmax(dim=1)
            probabilities = sm(predicted_label)
            prob_arr = (probabilities.detach().cpu().numpy())[0]
            pred_prob.append(prob_arr)
            
            
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
            loss_list.append(loss.item())
            pred_label.append(predicted_label.argmax(1))
            
            
            score += f1_score(predicted_label.argmax(1).to(device), label,num_classes=3)
            precision += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[0]
            recall += precision_recall(predicted_label.argmax(1).to(device), label, average='macro', num_classes=3)[1]
      
        
        score = score / len(loss_list)
        precision = precision / len(loss_list)
        recall = recall / len(loss_list)
            
    
    
    return total_acc/total_count, np.mean(loss_list),score,pred_label,pred_prob

# %% [markdown]
# ## 모델 학습

# %%
n_epochs = 100
early_stopping = EarlyStopping(path,patience = 3, verbose = True)


for epoch in range(1, n_epochs + 1):
    # 현재 learning rate 출력
    print(optimizer.param_groups[0]['lr'])
    epoch_start_time = time.time()
    accu_train, train_loss = train(final_dataloader)
    accu_test,test_loss,score,label,prob = evaluate(test_dataloader)
    if total_accu is not None and total_accu > accu_test:
        scheduler.step()
    else:
        total_accu = accu_test
    print('-' * 59)
    print(f'| end of epoch {epoch} | time: {time.time()- epoch_start_time}s | '
        f'valid accuracy {accu_test} | valid loss {test_loss}'
        ) 

    print('-' * 59)

    early_stopping(test_loss, model)
    if early_stopping.early_stop:
        print("Early stopping")
        break
print(score)
torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),


                }, path)
# Out:
# 0.0001
# -----------------------------------------------------------
# | end of epoch 1 | time: 42.807490825653076s | valid accuracy 0.35171589714176466 | valid loss 1.0996810310112957
# -----------------------------------------------------------
# Validation loss decreased (inf --> 1.099681).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 2 | time: 43.30708122253418s | valid accuracy 0.35171589714176466 | valid loss 1.0996076868579292
# -----------------------------------------------------------
# Validation loss decreased (1.099681 --> 1.099608).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 3 | time: 44.17605471611023s | valid accuracy 0.35171589714176466 | valid loss 1.0994519645650087
# -----------------------------------------------------------
# Validation loss decreased (1.099608 --> 1.099452).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 4 | time: 44.133010387420654s | valid accuracy 0.35171589714176466 | valid loss 1.0992315562857764
# -----------------------------------------------------------
# Validation loss decreased (1.099452 --> 1.099232).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 5 | time: 44.724337100982666s | valid accuracy 0.35171589714176466 | valid loss 1.0989993735555479
# -----------------------------------------------------------
# Validation loss decreased (1.099232 --> 1.098999).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 6 | time: 43.95357537269592s | valid accuracy 0.35171589714176466 | valid loss 1.0987774092852158
# -----------------------------------------------------------
# Validation loss decreased (1.098999 --> 1.098777).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 7 | time: 43.38486433029175s | valid accuracy 0.35171589714176466 | valid loss 1.0985751514770203
# -----------------------------------------------------------
# Validation loss decreased (1.098777 --> 1.098575).  Saving model ...
# 0.0001
# -----------------------------------------------------------
# | end of epoch 8 | time: 43.81568884849548s | valid accuracy 0.35171589714176466 | valid loss 1.0983918588460404
# -----------------------------------------------------------
# Validation loss decreased (1.098575 --> 1.098392).  Saving model ...
# 0.0001
# Adjusting learning rate of group 0 to 9.9975e-05.
# -----------------------------------------------------------
# | end of epoch 9 | time: 42.699134349823s | valid accuracy 0.3516967785106586 | valid loss 1.0982274786777089
# -----------------------------------------------------------
# Validation loss decreased (1.098392 --> 1.098227).  Saving model ...
# 9.997532801828658e-05
# Adjusting learning rate of group 0 to 9.9901e-05.
# -----------------------------------------------------------
# | end of epoch 10 | time: 42.52051877975464s | valid accuracy 0.3516394226173406 | valid loss 1.0980863414773154
# -----------------------------------------------------------
# Validation loss decreased (1.098227 --> 1.098086).  Saving model ...
# 9.990133642141359e-05
# Adjusting learning rate of group 0 to 9.9778e-05.
# -----------------------------------------------------------
# | end of epoch 11 | time: 42.474600076675415s | valid accuracy 0.3515055921995985 | valid loss 1.097969131969166
# -----------------------------------------------------------
# Validation loss decreased (1.098086 --> 1.097969).  Saving model ...
# 9.977809823015401e-05
# Adjusting learning rate of group 0 to 9.9606e-05.
# -----------------------------------------------------------
# | end of epoch 12 | time: 43.49273419380188s | valid accuracy 0.3514769142529395 | valid loss 1.0978774629419368
# -----------------------------------------------------------
# Validation loss decreased (1.097969 --> 1.097877).  Saving model ...
# 9.960573506572391e-05
# Adjusting learning rate of group 0 to 9.9384e-05.
# -----------------------------------------------------------
# | end of epoch 13 | time: 42.16663312911987s | valid accuracy 0.35156294809291655 | valid loss 1.0978114879094862
# -----------------------------------------------------------
# Validation loss decreased (1.097877 --> 1.097811).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 14 | time: 41.2090380191803s | valid accuracy 0.3519070834528248 | valid loss 1.0977722133153804
# -----------------------------------------------------------
# Validation loss decreased (1.097811 --> 1.097772).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 15 | time: 41.23251938819885s | valid accuracy 0.35289169295478445 | valid loss 1.0977579979539283
# -----------------------------------------------------------
# Validation loss decreased (1.097772 --> 1.097758).  Saving model ...
# 9.93844170297569e-05
# -----------------------------------------------------------
# | end of epoch 16 | time: 40.83141207695007s | valid accuracy 0.35320715036803363 | valid loss 1.0977697545599865
# -----------------------------------------------------------
# EarlyStopping counter: 1 out of 3
# 9.93844170297569e-05
# Adjusting learning rate of group 0 to 9.9114e-05.
# -----------------------------------------------------------
# | end of epoch 17 | time: 41.606754302978516s | valid accuracy 0.3526335914348533 | valid loss 1.0978114598205695
# -----------------------------------------------------------
# EarlyStopping counter: 2 out of 3
# 9.911436253643445e-05
# Adjusting learning rate of group 0 to 9.8796e-05.
# -----------------------------------------------------------
# | end of epoch 18 | time: 41.55846166610718s | valid accuracy 0.35319759105248066 | valid loss 1.097880923255868
# -----------------------------------------------------------
# EarlyStopping counter: 3 out of 3
# Early stopping
# tensor(0.3531)

# %%
wandb.init(project='result', entity='gyeongmoCho',name='1dcsnn+lstm')
wandb.log({'final_f1_score':0.3534})
# Out:
# wandb: Currently logged in as: gyeongmocho. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/jbj4278/wandb/run-20220607_085531-2zdf8m9e</code>
# Syncing run <strong><a href="https://wandb.ai/gyeongmocho/result/runs/2zdf8m9e" target="_blank">1dcsnn+lstm</a></strong> to <a href="https://wandb.ai/gyeongmocho/result" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# ### 예측 라벨 붙여주기

# %%
pred_label = list(map(list, label))

answer = sum(pred_label, [])

final_label = []
for i in answer:
    final_label.append(i.tolist())

# %%
a = a.tolist()

# %% [markdown]
# #### voting을 위한 확률값 생성

# %%
soft, hard = make_result(model,test_dataloader)

# %%
soft = pd.DataFrame(soft)

# %%
soft
# Out:
#                0         1         2
# 0       0.336474  0.330568  0.332958
# 1       0.336474  0.330568  0.332958
# 2       0.336474  0.330568  0.332958
# 3       0.336474  0.330568  0.332958
# 4       0.336474  0.330568  0.332958
# ...          ...       ...       ...
# 104605  0.337196  0.327918  0.334886
# 104606  0.337196  0.327918  0.334886
# 104607  0.337196  0.327918  0.334886
# 104608  0.336627  0.329800  0.333573
# 104609  0.336627  0.329800  0.333573
#
# [104610 rows x 3 columns]

# %%
"""
final_labels = pd.DataFrame(final_label,columns = ['pred_labels'])

test_set = test_set[:-10]

index = final_labels.index

test_set.index = index

plus_label_df = test_set.join(final_labels['pred_labels'],how='right') 

plus_label_df = plus_label_df.join(soft,how='right') 

"""

# %%
#plus_label_df.to_csv('final_1DCNNLSTM_label.csv')

# %%
#plus_label_df['pred_labels'].value_counts()
