# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
# !pip install -U finance-datareader
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-ryoe1srr\backtrader_82a04e2ddc9c4203b2cff4cd9b5198d6
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-ryoe1srr\backtrader_82a04e2ddc9c4203b2cff4cd9b5198d6'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: finance-datareader in c:\users\intel300\anaconda3\lib\site-packages (0.9.33)
# Requirement already satisfied: tqdm in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: lxml in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (4.8.0)
# Requirement already satisfied: requests-file in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (1.4.2)
# Requirement already satisfied: requests>=2.3.0 in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\intel300\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->finance-datareader) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\intel300\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.4)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/F_Lstm.csv"
data = pd.read_csv(path)

# %%
#preprocessing

eth_s_close=data.iloc[0].Close
eth_e_close=data.iloc[-1].Close
eth_roc=((eth_e_close - eth_s_close)/eth_s_close)*100
data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/F_Lstm_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
        
    def log(self, txt, dt=None):
        
        ''' Logging function fot this strategy'''
        dt = dt or self.data.datetime[0]
        if isinstance(dt, float):
            dt = bt.num2date(dt)
        print('%s, %s' % (dt.isoformat(), txt))         
        
        

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses == 0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
            
        trade_count = self.n_wins+self.n_losses    
        
        if abs(avg_loss) == 0 or avg_profit== 0:            
            print('-------------\n트레이딩 결과\n-------------')
        else:
            print('-------------\n트레이딩 결과\n-------------')         
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,
            timeframe=bt.TimeFrame.TFrame("Minutes"),

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
mcl=analyzers.tradeanalyzer.get_analysis().streak.lost.longest
mcw=analyzers.tradeanalyzer.get_analysis().streak.won.longest
won_count=analyzers.tradeanalyzer.get_analysis().won.total
lost_count=analyzers.tradeanalyzer.get_analysis().lost.total
total_trade_count = won_count+lost_count
win_rate= (won_count/total_trade_count)*100
lost_average_=analyzers.tradeanalyzer.get_analysis().lost.pnl.average
won_average_=analyzers.tradeanalyzer.get_analysis().won.pnl.average
sonikbi=won_average_/abs(lost_average_)
print(f"평균손실:{lost_average_:.0f}원 ", end='|')
print(f" 평균수익:{won_average_:.0f}원 ", end='|')
print(f" 손익비:{sonikbi:.2f} ", end='|')
print(f"\n총 거래횟수:{total_trade_count:.0f}회 ", end='|')
print(f" 승률:{win_rate:.2f}% ", end='|')
print(f" 최대연속 손실거래 횟수:{mcl:.0f}회 ", end='|')
print(f" 최대연속 수익거래 횟수:{mcw:.0f}회 ", end='|')
print(f" MDD:{mdd:.2f}% ")
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f"수익률:{ROR:.2f}% ", end='|')
print(f" 이더리움 자체 수익률:{eth_roc:.2f}%")
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-09T20:55:00, 매수 주문, 3933000원
# 2022-01-09T20:56:00, 매수 체결, 매수량: 0.508517670989066861 ETH, 진입가: 3933000원, 진입금액: 2000000원, 수수료 1000원
# 2022-01-11T16:51:00, 매도 주문, 3918000원
# 2022-01-11T16:52:00, 매도 체결, 매도량: 0.508517670989066861 ETH, 청산가: 3916000원, 청산금액: 1991355원, 수수료 996원
# 2022-01-11T16:52:00, [투자 이익] 총이익 -8645원 | 순이익 -10640원
# 2022-01-11T16:56:00, 매수 주문, 3916000원
# 2022-01-11T16:57:00, 매수 체결, 매수량: 0.510453511797584025 ETH, 진입가: 3917000원, 진입금액: 1999446원, 수수료 1000원
# 2022-01-11T16:57:00, 매도 주문, 3915000원
# 2022-01-11T16:58:00, 매도 체결, 매도량: 0.510453511797584025 ETH, 청산가: 3914000원, 청산금액: 1997915원, 수수료 999원
# 2022-01-11T16:58:00, [투자 이익] 총이익 -1531원 | 순이익 -3530원
# 2022-01-11T16:58:00, 매수 주문, 3914000원
# 2022-01-11T16:59:00, 매수 체결, 매수량: 0.510624156380494520 ETH, 진입가: 3914000원, 진입금액: 1998583원, 수수료 999원
# 2022-01-11T18:59:00, 매도 주문, 3927000원
# 2022-01-11T19:00:00, 매도 체결, 매도량: 0.510624156380494520 ETH, 청산가: 3929000원, 청산금액: 2006242원, 수수료 1003원
# 2022-01-11T19:00:00, [투자 이익] 총이익 7659원 | 순이익 5657원
# 2022-01-11T19:00:00, 매수 주문, 3930000원
# 2022-01-11T19:01:00, 매수 체결, 매수량: 0.508689222148829834 ETH, 진입가: 3931000원, 진입금액: 1999657원, 수수료 1000원
# 2022-01-11T19:01:00, 매도 주문, 3932000원
# 2022-01-11T19:02:00, 매도 체결, 매도량: 0.508689222148829834 ETH, 청산가: 3932000원, 청산금액: 2000166원, 수수료 1000원
# 2022-01-11T19:02:00, [투자 이익] 총이익 509원 | 순이익 -1491원
# 2022-01-11T19:07:00, 매수 주문, 3929000원
# 2022-01-11T19:08:00, 매수 체결, 매수량: 0.508780738304766778 ETH, 진입가: 3928000원, 진입금액: 1998491원, 수수료 999원
# 2022-01-11T19:08:00, 매도 주문, 3923000원
# 2022-01-11T19:09:00, 매도 체결, 매도량: 0.508780738304766778 ETH, 청산가: 3923000원, 청산금액: 1995947원, 수수료 998원
# 2022-01-11T19:09:00, [투자 이익] 총이익 -2544원 | 순이익 -4541원
# 2022-01-11T19:17:00, 매수 주문, 3931000원
# 2022-01-11T19:18:00, 매수 체결, 매수량: 0.508406361880298863 ETH, 진입가: 3932000원, 진입금액: 1999054원, 수수료 1000원
# 2022-01-11T19:18:00, 매도 주문, 3932000원
# 2022-01-11T19:19:00, 매도 체결, 매도량: 0.508406361880298863 ETH, 청산가: 3932000원, 청산금액: 1999054원, 수수료 1000원
# 2022-01-11T19:19:00, [투자 이익] 총이익 0원 | 순이익 -1999원
# 2022-01-11T19:21:00, 매수 주문, 3929000원
# 2022-01-11T19:22:00, 매수 체결, 매수량: 0.508614279249163692 ETH, 진입가: 3930000원, 진입금액: 1998854원, 수수료 999원
# 2022-01-12T14:23:00, 매도 주문, 4104000원
# 2022-01-12T14:24:00, 매도 체결, 매도량: 0.508614279249163692 ETH, 청산가: 4104000원, 청산금액: 2087353원, 수수료 1044원
# 2022-01-12T14:24:00, [투자 이익] 총이익 88499원 | 순이익 86456원
# 2022-01-12T14:24:00, 매수 주문, 4103000원
# 2022-01-12T14:25:00, 매수 체결, 매수량: 0.489152103649262815 ETH, 진입가: 4103000원, 진입금액: 2006991원, 수수료 1003원
# 2022-01-12T14:25:00, 매도 주문, 4104000원
# 2022-01-12T14:26:00, 매도 체결, 매도량: 0.489152103649262815 ETH, 청산가: 4104000원, 청산금액: 2007480원, 수수료 1004원
# 2022-01-12T14:26:00, [투자 이익] 총이익 489원 | 순이익 -1518원
# 2022-01-12T14:51:00, 매수 주문, 4118000원
# 2022-01-12T14:52:00, 매수 체결, 매수량: 0.487333480553073628 ETH, 진입가: 4120000원, 진입금액: 2007814원, 수수료 1004원
# 2022-01-13T23:24:00, 매도 주문, 3963000원
# 2022-01-13T23:25:00, 매도 체결, 매도량: 0.487333480553073628 ETH, 청산가: 3963000원, 청산금액: 1931303원, 수수료 966원
# 2022-01-13T23:25:00, [투자 이익] 총이익 -76511원 | 순이익 -78481원
# 2022-01-13T23:52:00, 매수 주문, 3963000원
# 2022-01-13T23:53:00, 매수 체결, 매수량: 0.504413621359250164 ETH, 진입가: 3962000원, 진입금액: 1998487원, 수수료 999원
# 2022-01-14T00:35:00, 매도 주문, 3962000원
# 2022-01-14T00:36:00, 매도 체결, 매도량: 0.504413621359250164 ETH, 청산가: 3962000원, 청산금액: 1998487원, 수수료 999원
# 2022-01-14T00:36:00, [투자 이익] 총이익 0원 | 순이익 -1998원
# 2022-01-14T00:36:00, 매수 주문, 3966000원
# 2022-01-14T00:37:00, 매수 체결, 매수량: 0.503981677450813348 ETH, 진입가: 3966000원, 진입금액: 1998791원, 수수료 999원
# 2022-01-14T00:38:00, 매도 주문, 3968000원
# 2022-01-14T00:39:00, 매도 체결, 매도량: 0.503981677450813348 ETH, 청산가: 3968000원, 청산금액: 1999799원, 수수료 1000원
# 2022-01-14T00:39:00, [투자 이익] 총이익 1008원 | 순이익 -991원
# 2022-01-14T00:39:00, 매수 주문, 3973000원
# 2022-01-14T00:40:00, 매수 체결, 매수량: 0.503068764050835893 ETH, 진입가: 3972000원, 진입금액: 1998189원, 수수료 999원
# 2022-01-14T00:46:00, 매도 주문, 3975000원
# 2022-01-14T00:47:00, 매도 체결, 매도량: 0.503068764050835893 ETH, 청산가: 3974000원, 청산금액: 1999195원, 수수료 1000원
# 2022-01-14T00:47:00, [투자 이익] 총이익 1006원 | 순이익 -993원
# 2022-01-14T00:50:00, 매수 주문, 3971000원
# 2022-01-14T00:51:00, 매수 체결, 매수량: 0.503297140293836098 ETH, 진입가: 3972000원, 진입금액: 1999096원, 수수료 1000원
# 2022-01-14T00:51:00, 매도 주문, 3972000원
# 2022-01-14T00:52:00, 매도 체결, 매도량: 0.503297140293836098 ETH, 청산가: 3972000원, 청산금액: 1999096원, 수수료 1000원
# 2022-01-14T00:52:00, [투자 이익] 총이익 0원 | 순이익 -1999원
# 2022-01-14T01:21:00, 매수 주문, 3970000원
# 2022-01-14T01:22:00, 매수 체결, 매수량: 0.503373560323097768 ETH, 진입가: 3971000원, 진입금액: 1998896원, 수수료 999원
# 2022-01-15T18:25:00, 매도 주문, 4048000원
# 2022-01-15T18:26:00, 매도 체결, 매도량: 0.503373560323097768 ETH, 청산가: 4046000원, 청산금액: 2036649원, 수수료 1018원
# 2022-01-15T18:26:00, [투자 이익] 총이익 37753원 | 순이익 35735원
# 2022-01-15T19:09:00, 매수 주문, 4044000원
# 2022-01-15T19:10:00, 매수 체결, 매수량: 0.495046132268413985 ETH, 진입가: 4045000원, 진입금액: 2002462원, 수수료 1001원
# 2022-01-15T19:10:00, 매도 주문, 4048000원
# 2022-01-15T19:11:00, 매도 체결, 매도량: 0.495046132268413985 ETH, 청산가: 4050000원, 청산금액: 2004937원, 수수료 1002원
# 2022-01-15T19:11:00, [투자 이익] 총이익 2475원 | 순이익 472원
# 2022-01-15T19:32:00, 매수 주문, 4044000원
# 2022-01-15T19:33:00, 매수 체결, 매수량: 0.495057792294155419 ETH, 진입가: 4044000원, 진입금액: 2002014원, 수수료 1001원
# 2022-01-15T19:33:00, 매도 주문, 4042000원
# 2022-01-15T19:34:00, 매도 체결, 매도량: 0.495057792294155419 ETH, 청산가: 4045000원, 청산금액: 2002509원, 수수료 1001원
# 2022-01-15T19:34:00, [투자 이익] 총이익 495원 | 순이익 -1507원
# 2022-01-15T19:51:00, 매수 주문, 4045000원
# 2022-01-15T19:52:00, 매수 체결, 매수량: 0.494898143805364732 ETH, 진입가: 4045000원, 진입금액: 2001863원, 수수료 1001원
# 2022-01-15T19:52:00, 매도 주문, 4046000원
# 2022-01-15T19:53:00, 매도 체결, 매도량: 0.494898143805364732 ETH, 청산가: 4046000원, 청산금액: 2002358원, 수수료 1001원
# 2022-01-15T19:53:00, [투자 이익] 총이익 495원 | 순이익 -1507원
# 2022-01-15T20:20:00, 매수 주문, 4059000원
# 2022-01-15T20:21:00, 매수 체결, 매수량: 0.493154045445431011 ETH, 진입가: 4059000원, 진입금액: 2001712원, 수수료 1001원
# 2022-01-15T20:21:00, 매도 주문, 4059000원
# 2022-01-15T20:22:00, 매도 체결, 매도량: 0.493154045445431011 ETH, 청산가: 4055000원, 청산금액: 1999740원, 수수료 1000원
# 2022-01-15T20:22:00, [투자 이익] 총이익 -1973원 | 순이익 -3973원
# 2022-01-15T21:52:00, 매수 주문, 4039000원
# 2022-01-15T21:53:00, 매수 체결, 매수량: 0.495497632148697464 ETH, 진입가: 4039000원, 진입금액: 2001315원, 수수료 1001원
# 2022-01-21T23:02:00, 매도 주문, 3165000원
# 2022-01-21T23:03:00, 매도 체결, 매도량: 0.495497632148697464 ETH, 청산가: 3169000원, 청산금액: 1570232원, 수수료 785원
# 2022-01-21T23:03:00, [투자 이익] 총이익 -431083원 | 순이익 -432869원
# 2022-01-21T23:03:00, 매수 주문, 3166000원
# 2022-01-21T23:04:00, 매수 체결, 매수량: 0.618454853096975898 ETH, 진입가: 3166000원, 진입금액: 1958028원, 수수료 979원
# 2022-01-22T10:01:00, 매도 주문, 2965000원
# 2022-01-22T10:02:00, 매도 체결, 매도량: 0.618454853096975898 ETH, 청산가: 2964000원, 청산금액: 1833100원, 수수료 917원
# 2022-01-22T10:02:00, [투자 이익] 총이익 -124928원 | 순이익 -126823원
# 2022-01-22T10:02:00, 매수 주문, 2947000원
# 2022-01-22T10:03:00, 매수 체결, 매수량: 0.660110526114690233 ETH, 진입가: 2946000원, 진입금액: 1944686원, 수수료 972원
# 2022-01-24T12:38:00, 매도 주문, 2738000원
# 2022-01-24T12:39:00, 매도 체결, 매도량: 0.660110526114690233 ETH, 청산가: 2738000원, 청산금액: 1807383원, 수수료 904원
# 2022-01-24T12:39:00, [투자 이익] 총이익 -137303원 | 순이익 -139179원
# 2022-01-24T12:39:00, 매수 주문, 2738000원
# 2022-01-24T12:40:00, 매수 체결, 매수량: 0.705415565414640122 ETH, 진입가: 2737000원, 진입금액: 1930722원, 수수료 965원
# 2022-02-10T06:54:00, 매도 주문, 3860000원
# 2022-02-10T06:55:00, 매도 체결, 매도량: 0.705415565414640122 ETH, 청산가: 3860000원, 청산금액: 2722904원, 수수료 1361원
# 2022-02-10T06:55:00, [투자 이익] 총이익 792182원 | 순이익 789855원
# 2022-02-10T06:55:00, 매수 주문, 3863000원
# 2022-02-10T06:56:00, 매수 체결, 매수량: 0.520427984669193933 ETH, 진입가: 3862000원, 진입금액: 2009893원, 수수료 1005원
# 2022-02-10T06:58:00, 매도 주문, 3852000원
# 2022-02-10T06:59:00, 매도 체결, 매도량: 0.520427984669193933 ETH, 청산가: 3854000원, 청산금액: 2005729원, 수수료 1003원
# 2022-02-10T06:59:00, [투자 이익] 총이익 -4163원 | 순이익 -6171원
# 2022-02-10T07:03:00, 매수 주문, 3856000원
# 2022-02-10T07:04:00, 매수 체결, 매수량: 0.521212702612260270 ETH, 진입가: 3856000원, 진입금액: 2009796원, 수수료 1005원
# 2022-02-10T07:05:00, 매도 주문, 3856000원
# 2022-02-10T07:06:00, 매도 체결, 매도량: 0.521212702612260270 ETH, 청산가: 3856000원, 청산금액: 2009796원, 수수료 1005원
# 2022-02-10T07:06:00, [투자 이익] 총이익 0원 | 순이익 -2010원
# 2022-02-10T07:07:00, 매수 주문, 3856000원
# 2022-02-10T07:08:00, 매수 체결, 매수량: 0.521160581341998941 ETH, 진입가: 3856000원, 진입금액: 2009595원, 수수료 1005원
# 2022-02-10T07:08:00, 매도 주문, 3858000원
# 2022-02-10T07:09:00, 매도 체결, 매도량: 0.521160581341998941 ETH, 청산가: 3858000원, 청산금액: 2010638원, 수수료 1005원
# 2022-02-10T07:09:00, [투자 이익] 총이익 1042원 | 순이익 -968원
# 2022-02-10T07:10:00, 매수 주문, 3859000원
# 2022-02-10T07:11:00, 매수 체결, 매수량: 0.520730350384761009 ETH, 진입가: 3859000원, 진입금액: 2009498원, 수수료 1005원
# 2022-02-10T07:14:00, 매도 주문, 3865000원
# 2022-02-10T07:15:00, 매도 체결, 매도량: 0.520730350384761009 ETH, 청산가: 3863000원, 청산금액: 2011581원, 수수료 1006원
# 2022-02-10T07:15:00, [투자 이익] 총이익 2083원 | 순이익 72원
# 2022-02-10T07:15:00, 매수 주문, 3865000원
# 2022-02-10T07:16:00, 매수 체결, 매수량: 0.519923844834841664 ETH, 진입가: 3865000원, 진입금액: 2009506원, 수수료 1005원
# 2022-02-10T07:16:00, 매도 주문, 3863000원
# 2022-02-10T07:17:00, 매도 체결, 매도량: 0.519923844834841664 ETH, 청산가: 3862000원, 청산금액: 2007946원, 수수료 1004원
# 2022-02-10T07:17:00, [투자 이익] 총이익 -1560원 | 순이익 -3568원
# 2022-02-10T07:31:00, 매수 주문, 3858000원
# 2022-02-10T07:32:00, 매수 체결, 매수량: 0.520774704654162868 ETH, 진입가: 3858000원, 진입금액: 2009149원, 수수료 1005원
# 2022-02-10T07:32:00, 매도 주문, 3857000원
# 2022-02-10T07:33:00, 매도 체결, 매도량: 0.520774704654162868 ETH, 청산가: 3859000원, 청산금액: 2009670원, 수수료 1005원
# 2022-02-10T07:33:00, [투자 이익] 총이익 521원 | 순이익 -1489원
# 2022-02-10T07:42:00, 매수 주문, 3856000원
# 2022-02-10T07:43:00, 매수 체결, 매수량: 0.521006210349179155 ETH, 진입가: 3856000원, 진입금액: 2009000원, 수수료 1004원
# 2022-02-10T07:43:00, 매도 주문, 3856000원
# 2022-02-10T07:44:00, 매도 체결, 매도량: 0.521006210349179155 ETH, 청산가: 3856000원, 청산금액: 2009000원, 수수료 1004원
# 2022-02-10T07:44:00, [투자 이익] 총이익 0원 | 순이익 -2009원
# 2022-02-10T07:47:00, 매수 주문, 3856000원
# 2022-02-10T07:48:00, 매수 체결, 매수량: 0.520954109728144155 ETH, 진입가: 3856000원, 진입금액: 2008799원, 수수료 1004원
# 2022-02-10T07:48:00, 매도 주문, 3857000원
# 2022-02-10T07:49:00, 매도 체결, 매도량: 0.520954109728144155 ETH, 청산가: 3858000원, 청산금액: 2009841원, 수수료 1005원
# 2022-02-10T07:49:00, [투자 이익] 총이익 1042원 | 순이익 -967원
# 2022-02-10T07:51:00, 매수 주문, 3859000원
# 2022-02-10T07:52:00, 매수 체결, 매수량: 0.520524049218333063 ETH, 진입가: 3860000원, 진입금액: 2009223원, 수수료 1005원
# 2022-02-10T07:52:00, 매도 주문, 3861000원
# 2022-02-10T07:53:00, 매도 체결, 매도량: 0.520524049218333063 ETH, 청산가: 3861000원, 청산금액: 2009743원, 수수료 1005원
# 2022-02-10T07:53:00, [투자 이익] 총이익 521원 | 순이익 -1489원
# 2022-02-10T08:03:00, 매수 주문, 3870000원
# 2022-02-10T08:04:00, 매수 체결, 매수량: 0.519006049103170275 ETH, 진입가: 3870000원, 진입금액: 2008553원, 수수료 1004원
# 2022-02-10T08:04:00, 매도 주문, 3870000원
# 2022-02-10T08:05:00, 매도 체결, 매도량: 0.519006049103170275 ETH, 청산가: 3870000원, 청산금액: 2008553원, 수수료 1004원
# 2022-02-10T08:05:00, [투자 이익] 총이익 0원 | 순이익 -2009원
# 2022-02-10T08:51:00, 매수 주문, 3875000원
# 2022-02-10T08:52:00, 매수 체결, 매수량: 0.518284530242133057 ETH, 진입가: 3875000원, 진입금액: 2008353원, 수수료 1004원
# 2022-02-24T02:49:00, 매도 주문, 3144000원
# 2022-02-24T02:50:00, 매도 체결, 매도량: 0.518284530242133057 ETH, 청산가: 3145000원, 청산금액: 1630005원, 수수료 815원
# 2022-02-24T02:50:00, [투자 이익] 총이익 -378348원 | 순이익 -380167원
# 2022-02-24T02:50:00, 매수 주문, 3135000원
# 2022-02-24T02:51:00, 매수 체결, 매수량: 0.628496289030454736 ETH, 진입가: 3136000원, 진입금액: 1970964원, 수수료 985원
# 2022-02-24T02:59:00, 매도 주문, 3058000원
# 2022-02-24T03:00:00, 매도 체결, 매도량: 0.628496289030454736 ETH, 청산가: 3057000원, 청산금액: 1921313원, 수수료 961원
# 2022-02-24T03:00:00, [투자 이익] 총이익 -49651원 | 순이익 -51597원
# 2022-02-24T03:00:00, 매수 주문, 3037000원
# 2022-02-24T03:01:00, 매수 체결, 매수량: 0.647078080853222382 ETH, 진입가: 3041000원, 진입금액: 1967764원, 수수료 984원
# 2022-03-04T00:37:00, 매도 주문, 3444000원
# 2022-03-04T00:38:00, 매도 체결, 매도량: 0.647078080853222382 ETH, 청산가: 3445000원, 청산금액: 2229184원, 수수료 1115원
# 2022-03-04T00:38:00, [투자 이익] 총이익 261420원 | 순이익 259321원
# 2022-03-04T00:38:00, 매수 주문, 3442000원
# 2022-03-04T00:39:00, 매수 체결, 매수량: 0.578474212259176501 ETH, 진입가: 3442000원, 진입금액: 1991108원, 수수료 996원
# 2022-03-06T23:08:00, 매도 주문, 3232000원
# 2022-03-06T23:09:00, 매도 체결, 매도량: 0.578474212259176501 ETH, 청산가: 3234000원, 청산금액: 1870786원, 수수료 935원
# 2022-03-06T23:09:00, [투자 이익] 총이익 -120323원 | 순이익 -122254원
# 2022-03-06T23:09:00, 매수 주문, 3231000원
# 2022-03-06T23:10:00, 매수 체결, 매수량: 0.612467620021368897 ETH, 진입가: 3231000원, 진입금액: 1978883원, 수수료 989원
# 2022-03-07T19:24:00, 매도 주문, 3131000원
# 2022-03-07T19:25:00, 매도 체결, 매도량: 0.612467620021368897 ETH, 청산가: 3130000원, 청산금액: 1917024원, 수수료 959원
# 2022-03-07T19:25:00, [투자 이익] 총이익 -61859원 | 순이익 -63807원
# 2022-03-07T19:25:00, 매수 주문, 3127000원
# 2022-03-07T19:26:00, 매수 체결, 매수량: 0.630796981771755361 ETH, 진입가: 3127000원, 진입금액: 1972502원, 수수료 986원
# 2022-03-09T03:16:00, 매도 주문, 3267000원
# 2022-03-09T03:17:00, 매도 체결, 매도량: 0.630796981771755361 ETH, 청산가: 3267000원, 청산금액: 2060814원, 수수료 1030원
# 2022-03-09T03:17:00, [투자 이익] 총이익 88312원 | 순이익 86295원
# 2022-03-09T03:17:00, 매수 주문, 3263000원
# 2022-03-09T03:18:00, 매수 체결, 매수량: 0.607150368970276189 ETH, 진입가: 3263000원, 진입금액: 1981132원, 수수료 991원
# 2022-03-09T04:14:00, 매도 주문, 3360000원
# 2022-03-09T04:15:00, 매도 체결, 매도량: 0.607150368970276189 ETH, 청산가: 3360000원, 청산금액: 2040025원, 수수료 1020원
# 2022-03-09T04:15:00, [투자 이익] 총이익 58894원 | 순이익 56883원
# 2022-03-09T04:15:00, 매수 주문, 3355000원
# 2022-03-09T04:16:00, 매수 체결, 매수량: 0.592196707804571898 ETH, 진입가: 3353000원, 진입금액: 1985636원, 수수료 993원
# 2022-03-09T04:16:00, 매도 주문, 3351000원
# 2022-03-09T04:17:00, 매도 체결, 매도량: 0.592196707804571898 ETH, 청산가: 3349000원, 청산금액: 1983267원, 수수료 992원
# 2022-03-09T04:17:00, [투자 이익] 총이익 -2369원 | 순이익 -4353원
# 2022-03-09T04:17:00, 매수 주문, 3349000원
# 2022-03-09T04:18:00, 매수 체결, 매수량: 0.593127689126435320 ETH, 진입가: 3349000원, 진입금액: 1986385원, 수수료 993원
# 2022-03-09T04:19:00, 매도 주문, 3351000원
# 2022-03-09T04:20:00, 매도 체결, 매도량: 0.593127689126435320 ETH, 청산가: 3350000원, 청산금액: 1986978원, 수수료 993원
# 2022-03-09T04:20:00, [투자 이익] 총이익 593원 | 순이익 -1394원
# 2022-03-09T04:20:00, 매수 주문, 3354000원
# 2022-03-09T04:21:00, 매수 체결, 매수량: 0.592201930689884248 ETH, 진입가: 3354000원, 진입금액: 1986245원, 수수료 993원
# 2022-03-10T13:35:00, 매도 주문, 3260000원
# 2022-03-10T13:36:00, 매도 체결, 매도량: 0.592201930689884248 ETH, 청산가: 3260000원, 청산금액: 1930578원, 수수료 965원
# 2022-03-10T13:36:00, [투자 이익] 총이익 -55667원 | 순이익 -57625원
# 2022-03-10T13:36:00, 매수 주문, 3247000원
# 2022-03-10T13:37:00, 매수 체결, 매수량: 0.609942327134865292 ETH, 진입가: 3248000원, 진입금액: 1981093원, 수수료 991원
# 2022-03-16T01:58:00, 매도 주문, 3267000원
# 2022-03-16T01:59:00, 매도 체결, 매도량: 0.609942327134865292 ETH, 청산가: 3267000원, 청산금액: 1992682원, 수수료 996원
# 2022-03-16T01:59:00, [투자 이익] 총이익 11589원 | 순이익 9602원
# 2022-03-16T01:59:00, 매수 주문, 3274000원
# 2022-03-16T02:00:00, 매수 체결, 매수량: 0.605205539986377383 ETH, 진입가: 3273000원, 진입금액: 1980838원, 수수료 990원
# 2022-03-16T02:00:00, 매도 주문, 3270000원
# 2022-03-16T02:01:00, 매도 체결, 매도량: 0.605205539986377383 ETH, 청산가: 3271000원, 청산금액: 1979627원, 수수료 990원
# 2022-03-16T02:01:00, [투자 이익] 총이익 -1210원 | 순이익 -3191원
# 2022-03-16T02:01:00, 매수 주문, 3269000원
# 2022-03-16T02:02:00, 매수 체결, 매수량: 0.606033610753967222 ETH, 진입가: 3269000원, 진입금액: 1981124원, 수수료 991원
# 2022-03-16T03:03:00, 매도 주문, 3322000원
# 2022-03-16T03:04:00, 매도 체결, 매도량: 0.606033610753967222 ETH, 청산가: 3322000원, 청산금액: 2013244원, 수수료 1007원
# 2022-03-16T03:04:00, [투자 이익] 총이익 32120원 | 순이익 30123원
# -------------
# 트레이딩 결과
# -------------
# 평균손실:-44680원 | 평균수익:123679원 | 손익비:2.77 |
# 총 거래횟수:45회 | 승률:24.44% | 최대연속 손실거래 횟수:8회 | 최대연속 수익거래 횟수:2회 | MDD:4.03%
# 수익률:-0.79% | 이더리움 자체 수익률:-6.84%
# 최종 자본: 19841361원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
