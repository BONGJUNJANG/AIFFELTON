# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp3==0.0.1
# !pip install -U finance-datareader
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp3 import type3
from backtrader.feeds import GenericCSVData
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-ip3ox4nw\backtrader_3fa91d897cd041edb469a0db27b0a03d
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-ip3ox4nw\backtrader_3fa91d897cd041edb469a0db27b0a03d'
# Collecting backtesting-pp3==0.0.1
#   Downloading backtesting_pp3-0.0.1-py3-none-any.whl (2.1 kB)
# Installing collected packages: backtesting-pp3
# Successfully installed backtesting-pp3-0.0.1
# Requirement already satisfied: finance-datareader in c:\users\intel300\anaconda3\lib\site-packages (0.9.33)
# Requirement already satisfied: requests-file in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (1.4.2)
# Requirement already satisfied: lxml in c:\users\intel300\anaconda3\lib\site-packages (from finance-datareader) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\intel300\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\intel300\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->finance-datareader) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\intel300\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: colorama in c:\users\intel300\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.4)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
# path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/bilstm_1dcnn_ensamble.csv"
# data = pd.read_csv(path)

# %%
data = pd.read_csv("C:/Users/intel300/workspace/hackathon/JKMnim_model/bilstm_1dcnn_ensamble.csv")
data.rename(columns={'pred_label':'pred_labels'}, inplace=True)

# %%
#preprocessing

data.drop(['Unnamed: 0', 'BTC_close', 'DXY', 'BTCD', 'Kimchi_premium','S&P500','Ethereum DeFi','News_freq', 'signal','0','1','2', 'sum_0', 'sum_1', 'sum_2'], axis=1, inplace=True)
eth_s_close=data.iloc[0].Close
eth_e_close=data.iloc[-1].Close
eth_roc=((eth_e_close - eth_s_close)/eth_s_close)*100
data.drop(['Unnamed: 0.1'], axis=1, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/bilstm_1dcnn_ensamble_pp.csv"
data = type3.backtesting_pp3(data, backtesting_path)

data = data[['Open','High','Low','Close','up','Volume']]
# data.drop(['Unnamed: 0.1'], axis=1, inplace=True)
# data = data[['Open','High','Low','Close','up','Volume']]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104610 entries, 2022-01-09 20:55:00 to 2022-03-23 15:09:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Open    104610 non-null  float64
#  1   High    104610 non-null  float64
#  2   Low     104610 non-null  float64
#  3   Close   104610 non-null  float64
#  4   up      104610 non-null  int64
#  5   Volume  104610 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 5.6 MB

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
        
    def log(self, txt, dt=None):
        
        ''' Logging function fot this strategy'''
        dt = dt or self.data.datetime[0]
        if isinstance(dt, float):
            dt = bt.num2date(dt)
        print('%s, %s' % (dt.isoformat(), txt))         
        
        

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses == 0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
            
        trade_count = self.n_wins+self.n_losses    
        
        if abs(avg_loss) == 0 or avg_profit== 0:            
            print('-------------\n트레이딩 결과\n-------------')
        else:
            print('-------------\n트레이딩 결과\n-------------')         
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,
            timeframe=bt.TimeFrame.TFrame("Minutes"),

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
mcl=analyzers.tradeanalyzer.get_analysis().streak.lost.longest
mcw=analyzers.tradeanalyzer.get_analysis().streak.won.longest
won_count=analyzers.tradeanalyzer.get_analysis().won.total
lost_count=analyzers.tradeanalyzer.get_analysis().lost.total
total_trade_count = won_count+lost_count
win_rate= (won_count/total_trade_count)*100
lost_average_=analyzers.tradeanalyzer.get_analysis().lost.pnl.average
won_average_=analyzers.tradeanalyzer.get_analysis().won.pnl.average
sonikbi=won_average_/abs(lost_average_)
print(f"평균손실:{lost_average_:.0f}원 ", end='|')
print(f" 평균수익:{won_average_:.0f}원 ", end='|')
print(f" 손익비:{sonikbi:.2f} ", end='|')
print(f"\n총 거래횟수:{total_trade_count:.0f}회 ", end='|')
print(f" 승률:{win_rate:.2f}% ", end='|')
print(f" 최대연속 손실거래 횟수:{mcl:.0f}회 ", end='|')
print(f" 최대연속 수익거래 횟수:{mcw:.0f}회 ", end='|')
print(f" MDD:{mdd:.2f}% ")
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f"수익률:{ROR:.2f}% ", end='|')
print(f" 이더리움 자체 수익률:{eth_roc:.2f}%")
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-12T14:31:00, 매수 주문, 4104000원
# 2022-01-12T14:32:00, 매수 체결, 매수량: 0.487329434697855723 ETH, 진입가: 4105000원, 진입금액: 2000487원, 수수료 1000원
# 2022-01-12T15:03:00, 매도 주문, 4115000원
# 2022-01-12T15:04:00, 매도 체결, 매도량: 0.487329434697855723 ETH, 청산가: 4114000원, 청산금액: 2004873원, 수수료 1002원
# 2022-01-12T15:04:00, [투자 이익] 총이익 4386원 | 순이익 2383원
# 2022-01-14T01:11:00, 매수 주문, 3977000원
# 2022-01-14T01:12:00, 매수 체결, 매수량: 0.502951553547910213 ETH, 진입가: 3978000원, 진입금액: 2000741원, 수수료 1000원
# 2022-01-14T01:43:00, 매도 주문, 3966000원
# 2022-01-14T01:44:00, 매도 체결, 매도량: 0.502951553547910213 ETH, 청산가: 3966000원, 청산금액: 1994706원, 수수료 997원
# 2022-01-14T01:44:00, [투자 이익] 총이익 -6035원 | 순이익 -8033원
# 2022-01-14T03:19:00, 매수 주문, 3973000원
# 2022-01-14T03:20:00, 매수 체결, 매수량: 0.503255729735391899 ETH, 진입가: 3973000원, 진입금액: 1999435원, 수수료 1000원
# 2022-01-14T04:23:00, 매도 주문, 3986000원
# 2022-01-14T04:24:00, 매도 체결, 매도량: 0.503255729735391899 ETH, 청산가: 3987000원, 청산금액: 2006481원, 수수료 1003원
# 2022-01-14T04:24:00, [투자 이익] 총이익 7046원 | 순이익 5043원
# 2022-01-15T20:26:00, 매수 주문, 4065000원
# 2022-01-15T20:27:00, 매수 체결, 매수량: 0.491989981913876162 ETH, 진입가: 4066000원, 진입금액: 2000431원, 수수료 1000원
# 2022-01-15T20:59:00, 매도 주문, 4061000원
# 2022-01-15T21:00:00, 매도 체결, 매도량: 0.491989981913876162 ETH, 청산가: 4065000원, 청산금액: 1999939원, 수수료 1000원
# 2022-01-15T21:00:00, [투자 이익] 총이익 -492원 | 순이익 -2492원
# 2022-01-15T22:03:00, 매수 주문, 4046000원
# 2022-01-15T22:04:00, 매수 체결, 매수량: 0.494238768896334224 ETH, 진입가: 4046000원, 진입금액: 1999690원, 수수료 1000원
# 2022-01-16T00:43:00, 매도 주문, 4036000원
# 2022-01-16T00:44:00, 매도 체결, 매도량: 0.494238768896334224 ETH, 청산가: 4036000원, 청산금액: 1994748원, 수수료 997원
# 2022-01-16T00:44:00, [투자 이익] 총이익 -4942원 | 순이익 -6940원
# 2022-01-24T14:42:00, 매수 주문, 2751000원
# 2022-01-24T14:43:00, 매수 체결, 매수량: 0.726643438131283514 ETH, 진입가: 2750000원, 진입금액: 1998269원, 수수료 999원
# 2022-01-24T15:14:00, 매도 주문, 2703000원
# 2022-01-24T15:15:00, 매도 체결, 매도량: 0.726643438131283514 ETH, 청산가: 2703000원, 청산금액: 1964117원, 수수료 982원
# 2022-01-24T15:15:00, [투자 이익] 총이익 -34152원 | 순이익 -36133원
# 2022-01-25T18:58:00, 매수 주문, 3029000원
# 2022-01-25T18:59:00, 매수 체결, 매수량: 0.658759575703710021 ETH, 진입가: 3035000원, 진입금액: 1999335원, 수수료 1000원
# 2022-01-25T19:30:00, 매도 주문, 3020000원
# 2022-01-25T19:31:00, 매도 체결, 매도량: 0.658759575703710021 ETH, 청산가: 3020000원, 청산금액: 1989454원, 수수료 995원
# 2022-01-25T19:31:00, [투자 이익] 총이익 -9881원 | 순이익 -11876원
# 2022-01-26T02:26:00, 매수 주문, 2997000원
# 2022-01-26T02:27:00, 매수 체결, 매수량: 0.665397122449595479 ETH, 진입가: 2997000원, 진입금액: 1994195원, 수수료 997원
# 2022-01-26T02:58:00, 매도 주문, 2987000원
# 2022-01-26T02:59:00, 매도 체결, 매도량: 0.665397122449595479 ETH, 청산가: 2987000원, 청산금액: 1987541원, 수수료 994원
# 2022-01-26T02:59:00, [투자 이익] 총이익 -6654원 | 순이익 -8645원
# 2022-01-26T14:10:00, 매수 주문, 3206000원
# 2022-01-26T14:11:00, 매수 체결, 매수량: 0.621750059900171959 ETH, 진입가: 3206000원, 진입금액: 1993331원, 수수료 997원
# 2022-02-14T08:19:00, 매도 주문, 3506000원
# 2022-02-14T08:20:00, 매도 체결, 매도량: 0.576223823827560433 ETH, 청산가: 3506000원, 청산금액: 2020241원, 수수료 1010원
# 2022-02-14T08:20:00, [투자 이익] 총이익 10948원 | 순이익 8933원
# 2022-02-14T13:07:00, 매수 주문, 3560000원
# 2022-02-14T13:08:00, 매수 체결, 매수량: 0.564497078221389503 ETH, 진입가: 3561000원, 진입금액: 2010174원, 수수료 1005원
# 2022-02-14T13:39:00, 매도 주문, 3575000원
# 2022-02-14T13:40:00, 매도 체결, 매도량: 0.564497078221389503 ETH, 청산가: 3575000원, 청산금액: 2018077원, 수수료 1009원
# 2022-02-14T13:40:00, [투자 이익] 총이익 7903원 | 순이익 5889원
# 2022-02-16T20:03:00, 매수 주문, 3837000원
# 2022-02-16T20:04:00, 매수 체결, 매수량: 0.523898483664359316 ETH, 진입가: 3837000원, 진입금액: 2010198원, 수수료 1005원
# 2022-02-16T22:11:00, 매도 주문, 3798000원
# 2022-02-16T22:12:00, 매도 체결, 매도량: 0.523898483664359316 ETH, 청산가: 3798000원, 청산금액: 1989766원, 수수료 995원
# 2022-02-16T22:12:00, [투자 이익] 총이익 -20432원 | 순이익 -22432원
# 2022-02-16T22:43:00, 매수 주문, 3816000원
# 2022-02-16T22:44:00, 매수 체결, 매수량: 0.526193731521938379 ETH, 진입가: 3816000원, 진입금액: 2007955원, 수수료 1004원
# 2022-02-16T23:15:00, 매도 주문, 3813000원
# 2022-02-16T23:16:00, 매도 체결, 매도량: 0.526193731521938379 ETH, 청산가: 3813000원, 청산금액: 2006377원, 수수료 1003원
# 2022-02-16T23:16:00, [투자 이익] 총이익 -1579원 | 순이익 -3586원
# 2022-02-19T16:19:00, 매수 주문, 3385000원
# 2022-02-19T16:20:00, 매수 체결, 매수량: 0.593086175707347452 ETH, 진입가: 3384000원, 진입금액: 2007004원, 수수료 1004원
# 2022-02-19T20:04:00, 매도 주문, 3350000원
# 2022-02-19T20:05:00, 매도 체결, 매도량: 0.593086175707347452 ETH, 청산가: 3346000원, 청산금액: 1984466원, 수수료 992원
# 2022-02-19T20:05:00, [투자 이익] 총이익 -22537원 | 순이익 -24533원
# 2022-02-19T20:36:00, 매수 주문, 3360000원
# 2022-02-19T20:38:00, 매수 체결, 매수량: 0.596768870179630428 ETH, 진입가: 3360000원, 진입금액: 2005143원, 수수료 1003원
# 2022-02-19T21:09:00, 매도 주문, 3356000원
# 2022-02-19T21:10:00, 매도 체결, 매도량: 0.596768870179630428 ETH, 청산가: 3356000원, 청산금액: 2002756원, 수수료 1001원
# 2022-02-19T21:10:00, [투자 이익] 총이익 -2387원 | 순이익 -4391원
# 2022-02-19T23:49:00, 매수 주문, 3372000원
# 2022-02-19T23:50:00, 매수 체결, 매수량: 0.594514917339525439 ETH, 진입가: 3372000원, 진입금액: 2004704원, 수수료 1002원
# 2022-02-20T00:53:00, 매도 주문, 3340000원
# 2022-02-20T00:54:00, 매도 체결, 매도량: 0.594514917339525439 ETH, 청산가: 3340000원, 청산금액: 1985680원, 수수료 993원
# 2022-02-25T20:05:00, 매도 주문, 3266000원
# 2022-02-25T20:06:00, 매도 체결, 매도량: 0.604232852052764779 ETH, 청산가: 3267000원, 청산금액: 1974029원, 수수료 987원
# 2022-02-25T20:06:00, [투자 이익] 총이익 -10272원 | 순이익 -12251원
# 2022-02-25T21:09:00, 매수 주문, 3320000원
# 2022-02-25T21:10:00, 매수 체결, 매수량: 0.596947924131925989 ETH, 진입가: 3321000원, 진입금액: 1982464원, 수수료 991원
# 2022-02-25T21:41:00, 매도 주문, 3312000원
# 2022-02-25T21:42:00, 매도 체결, 매도량: 0.596947924131925989 ETH, 청산가: 3312000원, 청산금액: 1977092원, 수수료 989원
# 2022-02-25T21:42:00, [투자 이익] 총이익 -5373원 | 순이익 -7352원
# 2022-02-28T17:25:00, 매수 주문, 3397000원
# 2022-02-28T17:26:00, 매수 체결, 매수량: 0.583200434856413596 ETH, 진입가: 3397000원, 진입금액: 1981132원, 수수료 991원
# 2022-02-28T23:17:00, 매도 주문, 3518000원
# 2022-02-28T23:18:00, 매도 체결, 매도량: 0.583200434856413596 ETH, 청산가: 3519000원, 청산금액: 2052282원, 수수료 1026원
# 2022-02-28T23:18:00, [투자 이익] 총이익 71150원 | 순이익 69134원
# 2022-02-28T23:49:00, 매수 주문, 3533000원
# 2022-02-28T23:50:00, 매수 체결, 매수량: 0.562707402151743974 ETH, 진입가: 3532000원, 진입금액: 1987483원, 수수료 994원
# 2022-03-01T00:53:00, 매도 주문, 3567000원
# 2022-03-01T00:54:00, 매도 체결, 매도량: 0.562707402151743974 ETH, 청산가: 3567000원, 청산금액: 2007177원, 수수료 1004원
# 2022-03-01T00:54:00, [투자 이익] 총이익 19695원 | 순이익 17697원
# 2022-03-01T02:29:00, 매수 주문, 3521000원
# 2022-03-01T02:30:00, 매수 체결, 매수량: 0.565127803100610282 ETH, 진입가: 3521000원, 진입금액: 1989815원, 수수료 995원
# 2022-03-01T03:33:00, 매도 주문, 3516000원
# 2022-03-01T03:34:00, 매도 체결, 매도량: 0.565127803100610282 ETH, 청산가: 3517000원, 청산금액: 1987554원, 수수료 994원
# 2022-03-01T03:34:00, [투자 이익] 총이익 -2261원 | 순이익 -4249원
# 2022-03-01T04:37:00, 매수 주문, 3535000원
# 2022-03-01T04:38:00, 매수 체결, 매수량: 0.562769469624355811 ETH, 진입가: 3534000원, 진입금액: 1988827원, 수수료 994원
# 2022-03-01T15:17:00, 매도 주문, 3613000원
# 2022-03-01T15:18:00, 매도 체결, 매도량: 0.562769469624355811 ETH, 청산가: 3613000원, 청산금액: 2033286원, 수수료 1017원
# 2022-03-01T15:18:00, [투자 이익] 총이익 44459원 | 순이익 42448원
# 2022-03-01T19:33:00, 매수 주문, 3586000원
# 2022-03-01T19:34:00, 매수 체결, 매수량: 0.555949483620234330 ETH, 진입가: 3586000원, 진입금액: 1993635원, 수수료 997원
# 2022-03-01T23:49:00, 매도 주문, 3607000원
# 2022-03-01T23:50:00, 매도 체결, 매도량: 0.555949483620234330 ETH, 청산가: 3607000원, 청산금액: 2005310원, 수수료 1003원
# 2022-03-01T23:50:00, [투자 이익] 총이익 11675원 | 순이익 9675원
# 2022-03-02T04:05:00, 매수 주문, 3658000원
# 2022-03-02T04:06:00, 매수 체결, 매수량: 0.545271294408414153 ETH, 진입가: 3658000원, 진입금액: 1994602원, 수수료 997원
# 2022-03-02T08:53:00, 매도 주문, 3621000원
# 2022-03-02T08:54:00, 매도 체결, 매도량: 0.545271294408414153 ETH, 청산가: 3621000원, 청산금액: 1974427원, 수수료 987원
# 2022-03-02T08:54:00, [투자 이익] 총이익 -20175원 | 순이익 -22160원
# 2022-03-03T22:45:00, 매수 주문, 3469000원
# 2022-03-03T22:46:00, 매수 체결, 매수량: 0.574340282406765046 ETH, 진입가: 3469000원, 진입금액: 1992386원, 수수료 996원
# 2022-03-04T03:01:00, 매도 주문, 3334000원
# 2022-03-04T03:02:00, 매도 체결, 매도량: 0.574340282406765046 ETH, 청산가: 3335000원, 청산금액: 1915425원, 수수료 958원
# 2022-03-04T03:02:00, [투자 이익] 총이익 -76962원 | 순이익 -78916원
# 2022-03-04T15:49:00, 매수 주문, 3303000원
# 2022-03-04T15:50:00, 매수 체결, 매수량: 0.600815891408035818 ETH, 진입가: 3303000원, 진입금액: 1984495원, 수수료 992원
# 2022-03-04T16:21:00, 매도 주문, 3286000원
# 2022-03-04T16:22:00, 매도 체결, 매도량: 0.600815891408035818 ETH, 청산가: 3286000원, 청산금액: 1974281원, 수수료 987원
# 2022-03-04T16:22:00, [투자 이익] 총이익 -10214원 | 순이익 -12193원
# 2022-03-04T16:53:00, 매수 주문, 3305000원
# 2022-03-04T16:54:00, 매수 체결, 매수량: 0.600083377763971026 ETH, 진입가: 3305000원, 진입금액: 1983276원, 수수료 992원
# 2022-03-04T19:01:00, 매도 주문, 3292000원
# 2022-03-04T19:02:00, 매도 체결, 매도량: 0.600083377763971026 ETH, 청산가: 3293000원, 청산금액: 1976075원, 수수료 988원
# 2022-03-04T19:02:00, [투자 이익] 총이익 -7201원 | 순이익 -9181원
# 2022-03-05T01:25:00, 매수 주문, 3234000원
# 2022-03-05T01:26:00, 매수 체결, 매수량: 0.612973870114497110 ETH, 진입가: 3235000원, 진입금액: 1982970원, 수수료 991원
# 2022-03-05T04:05:00, 매도 주문, 3251000원
# 2022-03-05T04:06:00, 매도 체결, 매도량: 0.612973870114497110 ETH, 청산가: 3251000원, 청산금액: 1992778원, 수수료 996원
# 2022-03-05T04:06:00, [투자 이익] 총이익 9808원 | 순이익 7820원
# 2022-03-06T10:31:00, 매수 주문, 3228000원
# 2022-03-06T10:32:00, 매수 체결, 매수량: 0.614355472960467330 ETH, 진입가: 3227000원, 진입금액: 1982525원, 수수료 991원
# 2022-03-06T14:47:00, 매도 주문, 3251000원
# 2022-03-06T14:48:00, 매도 체결, 매도량: 0.614355472960467330 ETH, 청산가: 3252000원, 청산금액: 1997884원, 수수료 999원
# 2022-03-06T14:48:00, [투자 이익] 총이익 15359원 | 순이익 13369원
# 2022-03-07T01:27:00, 매수 주문, 3181000원
# 2022-03-07T01:28:00, 매수 체결, 매수량: 0.623852981748923119 ETH, 진입가: 3181000원, 진입금액: 1984476원, 수수료 992원
# 2022-03-07T01:59:00, 매도 주문, 3168000원
# 2022-03-07T02:00:00, 매도 체결, 매도량: 0.623852981748923119 ETH, 청산가: 3170000원, 청산금액: 1977614원, 수수료 989원
# 2022-03-07T02:00:00, [투자 이익] 총이익 -6862원 | 순이익 -8843원
# 2022-03-07T03:35:00, 매수 주문, 3141000원
# 2022-03-07T03:36:00, 매수 체결, 매수량: 0.631516075182759096 ETH, 진입가: 3144000원, 진입금액: 1985487원, 수수료 993원
# 2022-03-07T07:51:00, 매도 주문, 3131000원
# 2022-03-07T07:52:00, 매도 체결, 매도량: 0.631516075182759096 ETH, 청산가: 3131000원, 청산금액: 1977277원, 수수료 989원
# 2022-03-07T07:52:00, [투자 이익] 총이익 -8210원 | 순이익 -10191원
# 2022-03-07T12:07:00, 매수 주문, 3184000원
# 2022-03-07T12:08:00, 매수 체결, 매수량: 0.622667362777236000 ETH, 진입가: 3184000원, 진입금액: 1982573원, 수수료 991원
# 2022-03-07T16:23:00, 매도 주문, 3246000원
# 2022-03-07T16:24:00, 매도 체결, 매도량: 0.622667362777236000 ETH, 청산가: 3248000원, 청산금액: 2022424원, 수수료 1011원
# 2022-03-07T16:24:00, [투자 이익] 총이익 39851원 | 순이익 37848원
# 2022-03-07T20:39:00, 매수 주문, 3080000원
# 2022-03-07T20:40:00, 매수 체결, 매수량: 0.644921332591111840 ETH, 진입가: 3082000원, 진입금액: 1987648원, 수수료 994원
# 2022-03-08T00:55:00, 매도 주문, 3142000원
# 2022-03-08T00:56:00, 매도 체결, 매도량: 0.644921332591111840 ETH, 청산가: 3142000원, 청산금액: 2026343원, 수수료 1013원
# 2022-03-08T00:56:00, [투자 이익] 총이익 38695원 | 순이익 36688원
# 2022-03-08T04:07:00, 매수 주문, 3185000원
# 2022-03-08T04:08:00, 매수 체결, 매수량: 0.624812098228404667 ETH, 진입가: 3185000원, 진입금액: 1990027원, 수수료 995원
# 2022-03-08T04:39:00, 매도 주문, 3165000원
# 2022-03-08T04:40:00, 매도 체결, 매도량: 0.624812098228404667 ETH, 청산가: 3165000원, 청산금액: 1977530원, 수수료 989원
# 2022-03-08T04:40:00, [투자 이익] 총이익 -12496원 | 순이익 -14480원
# 2022-03-08T05:11:00, 매수 주문, 3148000원
# 2022-03-08T05:12:00, 매수 체결, 매수량: 0.631695848417987316 ETH, 진입가: 3148000원, 진입금액: 1988579원, 수수료 994원
# 2022-03-08T09:27:00, 매도 주문, 3218000원
# 2022-03-08T09:28:00, 매도 체결, 매도량: 0.631695848417987316 ETH, 청산가: 3217000원, 청산금액: 2032166원, 수수료 1016원
# 2022-03-08T09:28:00, [투자 이익] 총이익 43587원 | 순이익 41577원
# 2022-03-08T11:03:00, 매수 주문, 3225000원
# 2022-03-08T11:04:00, 매수 체결, 매수량: 0.617902696114774996 ETH, 진입가: 3224000원, 진입금액: 1992118원, 수수료 996원
# 2022-03-08T11:35:00, 매도 주문, 3219000원
# 2022-03-08T11:36:00, 매도 체결, 매도량: 0.617902696114774996 ETH, 청산가: 3219000원, 청산금액: 1989029원, 수수료 995원
# 2022-03-08T11:36:00, [투자 이익] 총이익 -3090원 | 순이익 -5080원
# 2022-03-08T13:43:00, 매수 주문, 3215000원
# 2022-03-08T13:44:00, 매수 체결, 매수량: 0.619666620923340239 ETH, 진입가: 3215000원, 진입금액: 1992228원, 수수료 996원
# 2022-03-08T14:15:00, 매도 주문, 3210000원
# 2022-03-08T14:16:00, 매도 체결, 매도량: 0.619666620923340239 ETH, 청산가: 3210000원, 청산금액: 1989130원, 수수료 995원
# 2022-03-08T14:16:00, [투자 이익] 총이익 -3098원 | 순이익 -5089원
# 2022-03-08T14:47:00, 매수 주문, 3222000원
# 2022-03-08T14:48:00, 매수 체결, 매수량: 0.618162410011205754 ETH, 진입가: 3223000원, 진입금액: 1992337원, 수수료 996원
# 2022-03-08T22:16:00, 매도 주문, 3200000원
# 2022-03-08T22:17:00, 매도 체결, 매도량: 0.618162410011205754 ETH, 청산가: 3200000원, 청산금액: 1978120원, 수수료 989원
# 2022-03-08T22:17:00, [투자 이익] 총이익 -14218원 | 순이익 -16203원
# 2022-03-09T02:32:00, 매수 주문, 3252000원
# 2022-03-09T02:33:00, 매수 체결, 매수량: 0.611961558627030833 ETH, 진입가: 3252000원, 진입금액: 1990099원, 수수료 995원
# 2022-03-09T11:04:00, 매도 주문, 3405000원
# 2022-03-09T11:05:00, 매도 체결, 매도량: 0.611961558627030833 ETH, 청산가: 3406000원, 청산금액: 2084341원, 수수료 1042원
# 2022-03-09T11:05:00, [투자 이익] 총이익 94242원 | 순이익 92205원
# 2022-03-09T19:36:00, 매수 주문, 3330000원
# 2022-03-09T19:37:00, 매수 체결, 매수량: 0.600396238635163226 ETH, 진입가: 3330000원, 진입금액: 1999319원, 수수료 1000원
# 2022-03-10T00:56:00, 매도 주문, 3337000원
# 2022-03-10T00:57:00, 매도 체결, 매도량: 0.600396238635163226 ETH, 청산가: 3337000원, 청산금액: 2003522원, 수수료 1002원
# 2022-03-10T00:57:00, [투자 이익] 총이익 4203원 | 순이익 2201원
# 2022-03-10T01:28:00, 매수 주문, 3353000원
# 2022-03-10T01:29:00, 매수 체결, 매수량: 0.596343456586933884 ETH, 진입가: 3352000원, 진입금액: 1998943원, 수수료 999원
# 2022-03-10T04:08:00, 매도 주문, 3285000원
# 2022-03-10T04:09:00, 매도 체결, 매도량: 0.596343456586933884 ETH, 청산가: 3282000원, 청산금액: 1957199원, 수수료 979원
# 2022-03-10T04:09:00, [투자 이익] 총이익 -41744원 | 순이익 -43722원
# 2022-03-10T07:20:00, 매수 주문, 3221000원
# 2022-03-10T07:21:00, 매수 체결, 매수량: 0.619424836577252669 ETH, 진입가: 3221000원, 진입금액: 1995167원, 수수료 998원
# 2022-03-10T07:52:00, 매도 주문, 3227000원
# 2022-03-10T07:53:00, 매도 체결, 매도량: 0.619424836577252669 ETH, 청산가: 3227000원, 청산금액: 1998884원, 수수료 999원
# 2022-03-10T07:53:00, [투자 이익] 총이익 3717원 | 순이익 1720원
# 2022-03-10T08:24:00, 매수 주문, 3209000원
# 2022-03-10T08:25:00, 매수 체결, 매수량: 0.621794749439066652 ETH, 진입가: 3209000원, 진입금액: 1995339원, 수수료 998원
# 2022-03-10T09:28:00, 매도 주문, 3226000원
# 2022-03-10T09:29:00, 매도 체결, 매도량: 0.621794749439066652 ETH, 청산가: 3226000원, 청산금액: 2005910원, 수수료 1003원
# 2022-03-10T09:29:00, [투자 이익] 총이익 10571원 | 순이익 8570원
# 2022-03-10T10:00:00, 매수 주문, 3229000원
# 2022-03-10T10:01:00, 매수 체결, 매수량: 0.618208838514518133 ETH, 진입가: 3229000원, 진입금액: 1996196원, 수수료 998원
# 2022-03-10T11:04:00, 매도 주문, 3217000원
# 2022-03-10T11:05:00, 매도 체결, 매도량: 0.618208838514518133 ETH, 청산가: 3216000원, 청산금액: 1988160원, 수수료 994원
# 2022-03-10T11:05:00, [투자 이익] 총이익 -8037원 | 순이익 -10029원
# 2022-03-10T12:40:00, 매수 주문, 3232000원
# 2022-03-10T12:41:00, 매수 체결, 매수량: 0.617324706149473545 ETH, 진입가: 3232000원, 진입금액: 1995193원, 수수료 998원
# 2022-03-10T16:56:00, 매도 주문, 3226000원
# 2022-03-10T16:57:00, 매도 체결, 매도량: 0.617324706149473545 ETH, 청산가: 3226000원, 청산금액: 1991490원, 수수료 996원
# 2022-03-10T16:57:00, [투자 이익] 총이익 -3704원 | 순이익 -5697원
# 2022-03-11T06:48:00, 매수 주문, 3205000원
# 2022-03-11T06:49:00, 매수 체결, 매수량: 0.622347494946581592 ETH, 진입가: 3205000원, 진입금액: 1994624원, 수수료 997원
# 2022-03-11T08:24:00, 매도 주문, 3240000원
# 2022-03-11T08:25:00, 매도 체결, 매도량: 0.622347494946581592 ETH, 청산가: 3240000원, 청산금액: 2016406원, 수수료 1008원
# 2022-03-11T08:25:00, [투자 이익] 총이익 21782원 | 순이익 19777원
# 2022-03-11T18:32:00, 매수 주문, 3212000원
# 2022-03-11T18:33:00, 매수 체결, 매수량: 0.621606907240305206 ETH, 진입가: 3212000원, 진입금액: 1996601원, 수수료 998원
# 2022-03-11T22:48:00, 매도 주문, 3208000원
# 2022-03-11T22:49:00, 매도 체결, 매도량: 0.621606907240305206 ETH, 청산가: 3208000원, 청산금액: 1994115원, 수수료 997원
# 2022-03-11T22:49:00, [투자 이익] 총이익 -2486원 | 순이익 -4482원
# 2022-03-12T07:20:00, 매수 주문, 3227000원
# 2022-03-12T07:21:00, 매수 체결, 매수량: 0.618578620227995146 ETH, 진입가: 3227000원, 진입금액: 1996153원, 수수료 998원
# 2022-03-12T11:36:00, 매도 주문, 3223000원
# 2022-03-12T11:37:00, 매도 체결, 매도량: 0.618578620227995146 ETH, 청산가: 3223000원, 청산금액: 1993679원, 수수료 997원
# 2022-03-12T11:37:00, [투자 이익] 총이익 -2474원 | 순이익 -4469원
# 2022-03-13T09:08:00, 매수 주문, 3215000원
# 2022-03-13T09:09:00, 매수 체결, 매수량: 0.620748455496928697 ETH, 진입가: 3215000원, 진입금액: 1995706원, 수수료 998원
# 2022-03-13T13:24:00, 매도 주문, 3205000원
# 2022-03-13T13:25:00, 매도 체결, 매도량: 0.620748455496928697 ETH, 청산가: 3205000원, 청산금액: 1989499원, 수수료 995원
# 2022-03-13T13:25:00, [투자 이익] 총이익 -6207원 | 순이익 -8200원
# 2022-03-14T02:19:00, 매수 주문, 3159000원
# 2022-03-14T02:20:00, 매수 체결, 매수량: 0.631492964771419474 ETH, 진입가: 3159000원, 진입금액: 1994886원, 수수료 997원
# 2022-03-14T06:35:00, 매도 주문, 3214000원
# 2022-03-14T06:36:00, 매도 체결, 매도량: 0.631492964771419474 ETH, 청산가: 3214000원, 청산금액: 2029618원, 수수료 1015원
# 2022-03-14T06:36:00, [투자 이익] 총이익 34732원 | 순이익 32720원
# 2022-03-14T08:43:00, 매수 주문, 3214000원
# 2022-03-14T08:44:00, 매수 체결, 매수량: 0.621704499622256490 ETH, 진입가: 3212000원, 진입금액: 1996915원, 수수료 998원
# 2022-03-14T10:19:00, 매도 주문, 3216000원
# 2022-03-14T10:20:00, 매도 체결, 매도량: 0.621704499622256490 ETH, 청산가: 3217000원, 청산금액: 2000023원, 수수료 1000원
# 2022-03-14T10:20:00, [투자 이익] 총이익 3109원 | 순이익 1110원
# 2022-03-14T10:51:00, 매수 주문, 3215000원
# 2022-03-14T10:52:00, 매수 체결, 매수량: 0.621545650738519417 ETH, 진입가: 3215000원, 진입금액: 1998269원, 수수료 999원
# 2022-03-15T02:19:00, 매도 주문, 3182000원
# 2022-03-15T02:20:00, 매도 체결, 매도량: 0.621545650738519417 ETH, 청산가: 3182000원, 청산금액: 1977758원, 수수료 989원
# 2022-03-15T02:20:00, [투자 이익] 총이익 -20511원 | 순이익 -22499원
# 2022-03-15T02:51:00, 매수 주문, 3188000원
# 2022-03-15T02:52:00, 매수 체결, 매수량: 0.626103941374063333 ETH, 진입가: 3188000원, 진입금액: 1996019원, 수수료 998원
# 2022-03-15T05:31:00, 매도 주문, 3171000원
# 2022-03-15T05:32:00, 매도 체결, 매도량: 0.626103941374063333 ETH, 청산가: 3169000원, 청산금액: 1984123원, 수수료 992원
# 2022-03-15T05:32:00, [투자 이익] 총이익 -11896원 | 순이익 -13886원
# 2022-03-15T06:03:00, 매수 주문, 3177000원
# 2022-03-15T06:04:00, 매수 체결, 매수량: 0.627834674370203683 ETH, 진입가: 3178000원, 진입금액: 1995259원, 수수료 998원
# 2022-03-15T07:39:00, 매도 주문, 3155000원
# 2022-03-15T07:40:00, 매도 체결, 매도량: 0.627834674370203683 ETH, 청산가: 3155000원, 청산금액: 1980818원, 수수료 990원
# 2022-03-15T07:40:00, [투자 이익] 총이익 -14440원 | 순이익 -16428원
# 2022-03-15T08:11:00, 매수 주문, 3158000원
# 2022-03-15T08:12:00, 매수 체결, 매수량: 0.631091810282915278 ETH, 진입가: 3156000원, 진입금액: 1991726원, 수수료 996원
# 2022-03-15T13:31:00, 매도 주문, 3162000원
# 2022-03-15T13:32:00, 매도 체결, 매도량: 0.631091810282915278 ETH, 청산가: 3160000원, 청산금액: 1994250원, 수수료 997원
# 2022-03-15T13:32:00, [투자 이익] 총이익 2524원 | 순이익 531원
# 2022-03-15T14:03:00, 매수 주문, 3160000원
# 2022-03-15T14:04:00, 매수 체결, 매수량: 0.630709200887301424 ETH, 진입가: 3160000원, 진입금액: 1993041원, 수수료 997원
# 2022-03-15T20:59:00, 매도 주문, 3246000원
# 2022-03-15T21:00:00, 매도 체결, 매도량: 0.630709200887301424 ETH, 청산가: 3246000원, 청산금액: 2047282원, 수수료 1024원
# 2022-03-15T21:00:00, [투자 이익] 총이익 54241원 | 순이익 52221원
# 2022-03-16T09:47:00, 매수 주문, 3302000원
# 2022-03-16T09:48:00, 매수 체결, 매수량: 0.605167522039509076 ETH, 진입가: 3302000원, 진입금액: 1998263원, 수수료 999원
# 2022-03-16T10:51:00, 매도 주문, 3307000원
# 2022-03-16T10:52:00, 매도 체결, 매도량: 0.605167522039509076 ETH, 청산가: 3306000원, 청산금액: 2000684원, 수수료 1000원
# 2022-03-16T10:52:00, [투자 이익] 총이익 2421원 | 순이익 421원
# 2022-03-16T11:23:00, 매수 주문, 3302000원
# 2022-03-16T11:24:00, 매수 체결, 매수량: 0.605180277841911751 ETH, 진입가: 3302000원, 진입금액: 1998305원, 수수료 999원
# 2022-03-16T11:55:00, 매도 주문, 3326000원
# 2022-03-16T11:56:00, 매도 체결, 매도량: 0.605180277841911751 ETH, 청산가: 3327000원, 청산금액: 2013435원, 수수료 1007원
# 2022-03-16T11:56:00, [투자 이익] 총이익 15130원 | 순이익 13124원
# 2022-03-16T12:59:00, 매수 주문, 3299000원
# 2022-03-16T13:00:00, 매수 체결, 매수량: 0.606128415012278432 ETH, 진입가: 3301000원, 진입금액: 2000830원, 수수료 1000원
# 2022-03-16T14:03:00, 매도 주문, 3311000원
# 2022-03-16T14:04:00, 매도 체결, 매도량: 0.606128415012278432 ETH, 청산가: 3312000원, 청산금액: 2007497원, 수수료 1004원
# 2022-03-16T14:04:00, [투자 이익] 총이익 6667원 | 순이익 4663원
# 2022-03-16T18:19:00, 매수 주문, 3303000원
# 2022-03-16T18:20:00, 매수 체결, 매수량: 0.605535563433725943 ETH, 진입가: 3307000원, 진입금액: 2002506원, 수수료 1001원
# 2022-03-16T21:31:00, 매도 주문, 3392000원
# 2022-03-16T21:32:00, 매도 체결, 매도량: 0.605535563433725943 ETH, 청산가: 3392000원, 청산금액: 2053977원, 수수료 1027원
# 2022-03-16T21:32:00, [투자 이익] 총이익 51471원 | 순이익 49442원
# 2022-03-16T22:35:00, 매수 주문, 3380000원
# 2022-03-16T22:36:00, 매수 체결, 매수량: 0.593203607743731154 ETH, 진입가: 3380000원, 진입금액: 2005028원, 수수료 1003원
# 2022-03-17T02:51:00, 매도 주문, 3406000원
# 2022-03-17T02:52:00, 매도 체결, 매도량: 0.593203607743731154 ETH, 청산가: 3406000원, 청산금액: 2020451원, 수수료 1010원
# 2022-03-17T02:52:00, [투자 이익] 총이익 15423원 | 순이익 13411원
# 2022-03-17T15:39:00, 매수 주문, 3435000원
# 2022-03-17T15:40:00, 매수 체결, 매수량: 0.584095851403155009 ETH, 진입가: 3437000원, 진입금액: 2007537원, 수수료 1004원
# 2022-03-17T19:55:00, 매도 주문, 3453000원
# 2022-03-17T19:56:00, 매도 체결, 매도량: 0.584095851403155009 ETH, 청산가: 3453000원, 청산금액: 2016883원, 수수료 1008원
# 2022-03-17T19:56:00, [투자 이익] 총이익 9346원 | 순이익 7333원
# 2022-03-17T22:35:00, 매수 주문, 3445000원
# 2022-03-17T22:36:00, 매수 체결, 매수량: 0.582613231324027314 ETH, 진입가: 3445000원, 진입금액: 2007103원, 수수료 1004원
# 2022-03-17T23:39:00, 매도 주문, 3442000원
# 2022-03-17T23:40:00, 매도 체결, 매도량: 0.582613231324027314 ETH, 청산가: 3444000원, 청산금액: 2006520원, 수수료 1003원
# 2022-03-17T23:40:00, [투자 이익] 총이익 -583원 | 순이익 -2589원
# 2022-03-18T17:15:00, 매수 주문, 3565000원
# 2022-03-18T17:16:00, 매수 체결, 매수량: 0.562929492134814025 ETH, 진입가: 3564000원, 진입금액: 2006281원, 수수료 1003원
# 2022-03-18T17:47:00, 매도 주문, 3573000원
# 2022-03-18T17:48:00, 매도 체결, 매도량: 0.562929492134814025 ETH, 청산가: 3572000원, 청산금액: 2010784원, 수수료 1005원
# 2022-03-18T17:48:00, [투자 이익] 총이익 4503원 | 순이익 2495원
# 2022-03-18T19:55:00, 매수 주문, 3581000원
# 2022-03-18T19:56:00, 매수 체결, 매수량: 0.560483979282749623 ETH, 진입가: 3581000원, 진입금액: 2007093원, 수수료 1004원
# 2022-03-18T20:27:00, 매도 주문, 3602000원
# 2022-03-18T20:28:00, 매도 체결, 매도량: 0.560483979282749623 ETH, 청산가: 3602000원, 청산금액: 2018863원, 수수료 1009원
# 2022-03-18T20:28:00, [투자 이익] 총이익 11770원 | 순이익 9757원
# 2022-03-21T03:55:00, 매수 주문, 3481000원
# 2022-03-21T03:56:00, 매수 체결, 매수량: 0.576865512308779249 ETH, 진입가: 3482000원, 진입금액: 2008646원, 수수료 1004원
# 2022-03-21T09:15:00, 매도 주문, 3510000원
# 2022-03-21T09:16:00, 매도 체결, 매도량: 0.576865512308779249 ETH, 청산가: 3509000원, 청산금액: 2024221원, 수수료 1012원
# 2022-03-21T09:16:00, [투자 이익] 총이익 15575원 | 순이익 13559원
# -------------
# 트레이딩 결과
# -------------
# 평균손실:-15142원 | 평균수익:18998원 | 손익비:1.25 |
# 총 거래횟수:102회 | 승률:47.06% | 최대연속 손실거래 횟수:6회 | 최대연속 수익거래 횟수:8회 | MDD:1.54%
# 수익률:0.47% | 이더리움 자체 수익률:-6.84%
# 최종 자본: 20094247원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
